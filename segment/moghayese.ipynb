# %%
import matplotlib.pyplot as plt

# Data
epochs = list(range(1, 21))
train_loss = [0.3780, 0.3133, 0.2785, 0.2770, 0.2679, 0.2709, 0.2607, 0.2509, 0.2480, 0.2473, 
              0.2419, 0.2417, 0.2423, 0.2333, 0.2370, 0.2346, 0.2273, 0.2258, 0.2212, 0.2210]
val_loss = [0.2850, 0.2269, 0.2033, 0.2095, 0.2218, 0.2158, 0.1640, 0.1692, 0.1418, 0.1555, 
            0.1697, 0.1519, 0.1535, 0.1499, 0.1569, 0.1474, 0.1354, 0.1270, 0.1330, 0.1297]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet features: (64,128,256,512) Fold 1')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
import matplotlib.pyplot as plt

# Data
epochs = list(range(1, 21))
train_loss = [0.3579, 0.2984, 0.2839, 0.2718, 0.2720, 0.2676, 0.2649, 0.2563, 0.2515, 0.2534, 
              0.2490, 0.2391, 0.2420, 0.2317, 0.2327, 0.2286, 0.2237, 0.2192, 0.2201, 0.2153]
val_loss = [0.1992, 0.2336, 0.1715, 0.2096, 0.1593, 0.1570, 0.2247, 0.1642, 0.1662, 0.1488, 
            0.1570, 0.1365, 0.1253, 0.1267, 0.1303, 0.1321, 0.1497, 0.1159, 0.1154, 0.1450]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet features: (64,128,256,512) Fold 2')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 21))
train_loss = [0.3711, 0.3039, 0.2840, 0.2728, 0.2699, 0.2694, 0.2651, 0.2602, 0.2609, 0.2554, 
              0.2515, 0.2445, 0.2437, 0.2413, 0.2354, 0.2388, 0.2293, 0.2355, 0.2270, 0.2297]
val_loss = [0.2114, 0.2084, 0.1650, 0.1669, 0.1766, 0.1525, 0.1623, 0.1390, 0.1641, 0.1367, 
            0.1502, 0.1332, 0.1263, 0.1353, 0.1183, 0.1403, 0.1607, 0.1358, 0.1049, 0.1387]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet features: (64,128,256,512) Fold 3')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 21))
train_loss = [0.3575, 0.2941, 0.2811, 0.2764, 0.2640, 0.2566, 0.2520, 0.2506, 0.2503, 0.2450, 
              0.2404, 0.2371, 0.2362, 0.2294, 0.2283, 0.2258, 0.2196, 0.2215, 0.2187, 0.2184]
val_loss = [0.3190, 0.1910, 0.1732, 0.2450, 0.1628, 0.1855, 0.1644, 0.1598, 0.1666, 0.1616, 
            0.2022, 0.1656, 0.1504, 0.1653, 0.1403, 0.1532, 0.1305, 0.1625, 0.1375, 0.1247]


# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet features: (64,128,256,512) Fold 4')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 21))
train_loss = [0.3595, 0.2979, 0.2832, 0.2771, 0.2715, 0.2666, 0.2611, 0.2634, 0.2549, 0.2499, 
              0.2512, 0.2448, 0.2370, 0.2317, 0.2350, 0.2331, 0.2254, 0.2269, 0.2293, 0.2237]
val_loss = [0.2616, 0.3252, 0.2207, 0.1694, 0.1571, 0.2102, 0.1545, 0.1760, 0.1616, 0.1409, 
            0.1446, 0.1485, 0.1268, 0.1505, 0.1465, 0.1218, 0.1318, 0.1218, 0.1265, 0.1311]


# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet features: (64,128,256,512) Fold 5')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 51))
train_loss = [
    0.3780, 0.3133, 0.2785, 0.2770, 0.2679, 0.2709, 0.2607, 0.2509, 0.2480, 0.2473,
    0.2419, 0.2417, 0.2423, 0.2243, 0.2279, 0.2264, 0.2203, 0.2182, 0.2153, 0.2154,
    0.2169, 0.2128, 0.2096, 0.2112, 0.2020, 0.1979, 0.2037, 0.2014, 0.1976, 0.1968,
    0.2030, 0.1973, 0.1925, 0.1933, 0.1909, 0.1901, 0.1918, 0.1897, 0.1904, 0.1907,
    0.1866, 0.1876, 0.1861, 0.1851, 0.1833, 0.1847, 0.1861, 0.1888, 0.1812, 0.1863
]
val_loss = [
    0.2850, 0.2269, 0.2033, 0.2095, 0.2218, 0.2158, 0.1640, 0.1692, 0.1418, 0.1555,
    0.1697, 0.1519, 0.1535, 0.1404, 0.1435, 0.1407, 0.1330, 0.1232, 0.1206, 0.1301,
    0.1392, 0.1315, 0.1222, 0.1266, 0.1116, 0.1198, 0.1189, 0.1093, 0.1142, 0.1153,
    0.1148, 0.1153, 0.1082, 0.1087, 0.1023, 0.1050, 0.1015, 0.1054, 0.1067, 0.1102,
    0.1086, 0.1050, 0.1011, 0.1017, 0.0990, 0.1067, 0.1025, 0.1016, 0.0981, 0.1014
]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet with learning rate scheduling features: (64,128,256,512) Fold 1')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 51))
train_loss = [
    0.3660, 0.2884, 0.2880, 0.2729, 0.2717, 0.2638, 0.2677, 0.2512, 0.2474, 0.2471,
    0.2445, 0.2426, 0.2419, 0.2380, 0.2355, 0.2259, 0.2271, 0.2185, 0.2204, 0.2211,
    0.2205, 0.2143, 0.2121, 0.2092, 0.2084, 0.2068, 0.2073, 0.2073, 0.2062, 0.2029,
    0.2022, 0.2063, 0.2027, 0.2077, 0.2041, 0.1943, 0.1962, 0.1947, 0.1935, 0.1939,
    0.1943, 0.1892, 0.1896, 0.1909, 0.1894, 0.1908, 0.1918, 0.1873, 0.1919, 0.1903
]
val_loss = [
    0.4009, 0.3145, 0.1640, 0.1883, 0.1738, 0.2760, 0.2447, 0.1542, 0.1502, 0.1507,
    0.1311, 0.1547, 0.1418, 0.1370, 0.1393, 0.1272, 0.1330, 0.1194, 0.1121, 0.1187,
    0.1211, 0.1181, 0.1187, 0.1144, 0.1095, 0.1055, 0.1102, 0.1101, 0.1142, 0.1038,
    0.1049, 0.1078, 0.1032, 0.1103, 0.1062, 0.1083, 0.1061, 0.0995, 0.1049, 0.0997,
    0.0997, 0.0990, 0.0970, 0.0979, 0.0980, 0.0997, 0.0972, 0.0940, 0.0961, 0.0956
]


# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet with learning rate scheduling features: (64,128,256,512) Fold 2')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 51))
train_loss = [
    0.3684, 0.3067, 0.2855, 0.2767, 0.2759, 0.2712, 0.2633, 0.2650, 0.2540, 0.2578,
    0.2498, 0.2459, 0.2424, 0.2396, 0.2329, 0.2314, 0.2292, 0.2267, 0.2205, 0.2196,
    0.2261, 0.2135, 0.2151, 0.2101, 0.2106, 0.2041, 0.2036, 0.2016, 0.2061, 0.2042,
    0.2044, 0.1916, 0.1883, 0.1893, 0.1868, 0.1800, 0.1795, 0.1856, 0.1819, 0.1839,
    0.1794, 0.1756, 0.1724, 0.1716, 0.1727, 0.1677, 0.1699, 0.1723, 0.1704, 0.1662
]
val_loss = [
    0.2167, 0.1988, 0.1951, 0.2309, 0.1934, 0.1700, 0.1660, 0.1529, 0.1476, 0.1442,
    0.1433, 0.1330, 0.1415, 0.1323, 0.1375, 0.1291, 0.1340, 0.1365, 0.1271, 0.1240,
    0.1284, 0.1132, 0.1459, 0.1044, 0.1121, 0.1125, 0.1037, 0.1066, 0.1122, 0.1248,
    0.1129, 0.1029, 0.0990, 0.0999, 0.0965, 0.0908, 0.0891, 0.0952, 0.0994, 0.0950,
    0.0942, 0.0915, 0.0913, 0.0909, 0.0901, 0.0893, 0.0937, 0.0911, 0.0903, 0.0888
]


# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet with learning rate scheduling features: (64,128,256,512) Fold 3')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 51))
train_loss = [
    0.3705, 0.3039, 0.2819, 0.2764, 0.2693, 0.2612, 0.2545, 0.2516, 0.2471, 0.2449,
    0.2386, 0.2383, 0.2326, 0.2353, 0.2291, 0.2254, 0.2270, 0.2219, 0.2109, 0.2099,
    0.2157, 0.2082, 0.2103, 0.2053, 0.2067, 0.2007, 0.2066, 0.2012, 0.1998, 0.1955,
    0.1866, 0.1901, 0.1856, 0.1854, 0.1861, 0.1830, 0.1840, 0.1772, 0.1775, 0.1721,
    0.1755, 0.1705, 0.1728, 0.1739, 0.1709, 0.1683, 0.1738, 0.1693, 0.1687, 0.1686
]
val_loss = [
    0.2140, 0.2201, 0.1910, 0.3527, 0.2037, 0.1741, 0.1631, 0.1771, 0.2024, 0.1700,
    0.1522, 0.1575, 0.1532, 0.1493, 0.1707, 0.1417, 0.1511, 0.1353, 0.1374, 0.1262,
    0.1534, 0.1246, 0.1336, 0.1307, 0.1203, 0.1108, 0.1213, 0.1200, 0.1420, 0.1177,
    0.1119, 0.1063, 0.1039, 0.1063, 0.1083, 0.1079, 0.1108, 0.0991, 0.0999, 0.1015,
    0.1056, 0.0958, 0.1054, 0.1050, 0.0966, 0.0934, 0.0968, 0.0934, 0.0962, 0.0914
]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet with learning rate scheduling features: (64,128,256,512) Fold 4')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
# Data
epochs = list(range(1, 51))
train_loss = [
    0.3591, 0.2998, 0.2913, 0.2708, 0.2743, 0.2605, 0.2626, 0.2573, 0.2483, 0.2356,
    0.2386, 0.2286, 0.2316, 0.2284, 0.2241, 0.2250, 0.2226, 0.2161, 0.2195, 0.2160,
    0.2194, 0.2088, 0.2088, 0.2052, 0.2016, 0.1999, 0.1977, 0.1934, 0.1962, 0.1941,
    0.1916, 0.1943, 0.1898, 0.1926, 0.1926, 0.1909, 0.1893, 0.1887, 0.1879, 0.1930,
    0.1924, 0.1902, 0.1867, 0.1846, 0.1878, 0.1848, 0.1828, 0.1850, 0.1820, 0.1802
]
val_loss = [
    0.1977, 0.2531, 0.1614, 0.1772, 0.1454, 0.1673, 0.1545, 0.1907, 0.1515, 0.1497,
    0.1400, 0.1419, 0.1368, 0.1317, 0.1163, 0.1126, 0.1114, 0.1306, 0.1324, 0.1148,
    0.1323, 0.1064, 0.1150, 0.1066, 0.1163, 0.1101, 0.1028, 0.0999, 0.1016, 0.1080,
    0.1023, 0.0988, 0.0984, 0.1055, 0.1012, 0.0974, 0.1009, 0.0960, 0.0979, 0.1020,
    0.0986, 0.0949, 0.0980, 0.0971, 0.0934, 0.0953, 0.0945, 0.0993, 0.0977, 0.0931
]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='testLoss')
plt.title('Train and test Loss: Att Unet with learning rate scheduling features: (64,128,256,512) Fold 5')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Save the plot
plt.savefig('loss_plot.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, 26)
train_loss = [0.3673, 0.3142, 0.2959, 0.2861, 0.2678, 0.2655, 0.2572, 0.2535, 0.2485, 0.2372, 
              0.2426, 0.2359, 0.2328, 0.2307, 0.2323, 0.2270, 0.2244, 0.2194, 0.2246, 0.2154, 
              0.2170, 0.2123, 0.2080, 0.2124, 0.2069]
test_loss = [0.2261, 0.1886, 0.2215, 0.1582, 0.1657, 0.1773, 0.2235, 0.1551, 0.1695, 0.1612, 
             0.1499, 0.1331, 0.1451, 0.1331, 0.1492, 0.1275, 0.1502, 0.1254, 0.1339, 0.1301, 
             0.1271, 0.1082, 0.1310, 0.1413, 0.1160]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, test_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss U Net')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, 21)
train_loss = [0.5750, 0.4804, 0.4493, 0.4329, 0.4264, 0.4142, 0.4095, 0.4112, 0.3991, 0.4017, 
              0.3981, 0.3917, 0.3905, 0.3869, 0.3898, 0.3885, 0.3848, 0.4259, 0.3860, 0.3808]
val_loss = [0.4117, 0.3533, 0.3097, 0.3295, 0.3047, 0.3165, 0.3035, 0.2864, 0.2732, 0.2814, 
            0.2797, 0.2949, 0.2753, 0.2686, 0.2707, 0.3109, 0.2856, 0.2747, 0.3146, 0.3040]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='test Loss')
plt.title('Train and Test Loss U Net++ batch size: 2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_unetplusplus.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, 21)
train_loss = [0.6232, 0.5157, 0.4730, 0.4504, 0.4364, 0.4216, 0.4158, 0.4074, 0.4021, 0.4049, 
              0.3922, 0.3934, 0.3869, 0.3843, 0.3840, 0.3874, 0.3870, 0.3818, 0.3846, 0.3771]
val_loss = [0.4365, 0.4007, 0.3416, 0.3370, 0.3164, 0.3185, 0.3069, 0.2971, 0.3062, 0.2841, 
            0.2748, 0.2745, 0.2828, 0.2593, 0.2948, 0.2791, 0.2802, 0.2667, 0.2548, 0.2653]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss U Net++ batch size: 4')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_unetplusplus_batch4.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, 21)
train_loss = [0.6133, 0.5295, 0.4922, 0.4699, 0.4386, 0.3317, 0.3070, 0.2896, 0.2584, 0.2591, 
              0.2555, 0.2626, 0.2522, 0.2544, 0.2473, 0.2363, 0.2414, 0.2420, 0.2330, 0.2298]
val_loss = [0.4464, 0.4212, 0.3912, 0.3412, 0.2623, 0.2266, 0.2372, 0.1586, 0.1634, 0.1600, 
            0.1691, 0.1644, 0.1674, 0.1465, 0.1929, 0.1508, 0.1624, 0.1447, 0.1323, 0.1512]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss U Net++ batch size: 8')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_unetplusplus_batch8.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, 21)
train_loss = [0.6283, 0.5355, 0.5246, 0.5551, 0.4337, 0.3572, 0.3392, 0.2924, 0.2866, 0.2640, 
              0.2619, 0.2518, 0.2494, 0.2448, 0.2398, 0.2303, 0.2297, 0.2239, 0.2321, 0.2295]
val_loss = [0.4640, 0.4302, 0.4798, 0.4359, 0.3146, 0.4568, 0.2162, 0.1742, 0.1683, 0.1587, 
            0.1707, 0.1365, 0.1582, 0.1706, 0.1432, 0.1529, 0.1395, 0.1340, 0.1368, 0.1918]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss U Net++ batch size: 16')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_unetplusplus_batch16.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, 21)
train_loss = [0.6368, 0.5609, 0.5318, 0.6929, 0.5452, 0.8571, 0.5452, 0.4678, 0.4470, 0.3763, 
              0.3209, 0.3001, 0.2849, 0.2721, 0.2608, 0.2602, 0.2501, 0.2465, 0.2385, 0.2456]
val_loss = [0.4959, 0.4236, 0.9050, 0.4916, 0.4047, 0.5177, 0.4010, 0.3369, 0.3506, 0.2394, 
            0.2205, 0.1952, 0.1932, 0.1762, 0.1895, 0.1579, 0.1927, 0.1520, 0.1459, 0.1677]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss U Net++ batch size: 32')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_unetplusplus_batch32.png')

# %%
epochs = np.arange(1, 51)
train_loss = [0.3780, 0.3133, 0.2785, 0.2770, 0.2679, 0.2709, 0.2607, 0.2509, 0.2480, 0.2473, 
              0.2419, 0.2417, 0.2423, 0.2243, 0.2279, 0.2264, 0.2203, 0.2182, 0.2153, 0.2154, 
              0.2169, 0.2128, 0.2096, 0.2112, 0.2020, 0.1979, 0.2037, 0.2014, 0.1976, 0.1968, 
              0.2030, 0.1973, 0.1925, 0.1933, 0.1909, 0.1901, 0.1918, 0.1897, 0.1904, 0.1907, 
              0.1866, 0.1876, 0.1861, 0.1851, 0.1833, 0.1847, 0.1861, 0.1888, 0.1812, 0.1863]
val_loss = [0.2850, 0.2269, 0.2033, 0.2095, 0.2218, 0.2158, 0.1640, 0.1692, 0.1418, 0.1555, 
            0.1697, 0.1519, 0.1535, 0.1404, 0.1435, 0.1407, 0.1330, 0.1232, 0.1206, 0.1301, 
            0.1392, 0.1315, 0.1222, 0.1266, 0.1116, 0.1198, 0.1189, 0.1093, 0.1142, 0.1153, 
            0.1148, 0.1153, 0.1082, 0.1087, 0.1023, 0.1050, 0.1015, 0.1054, 0.1067, 0.1102, 
            0.1086, 0.1050, 0.1011, 0.1017, 0.0990, 0.1067, 0.1025, 0.1016, 0.0981, 0.1014]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss Attention U Net features [32, 64, 128, 256] Fold 1')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_fold1.png')

# %%
epochs = np.arange(1, 51)
train_loss = [0.3660, 0.2884, 0.2880, 0.2729, 0.2717, 0.2638, 0.2677, 0.2512, 0.2474, 0.2471, 
              0.2445, 0.2426, 0.2419, 0.2380, 0.2355, 0.2259, 0.2271, 0.2185, 0.2204, 0.2211, 
              0.2205, 0.2143, 0.2121, 0.2092, 0.2084, 0.2068, 0.2073, 0.2073, 0.2062, 0.2029, 
              0.2022, 0.2063, 0.2027, 0.2077, 0.2041, 0.1943, 0.1962, 0.1947, 0.1935, 0.1939, 
              0.1943, 0.1892, 0.1896, 0.1909, 0.1894, 0.1908, 0.1918, 0.1873, 0.1919, 0.1903]
val_loss = [0.4009, 0.3145, 0.1640, 0.1883, 0.1738, 0.2760, 0.2447, 0.1542, 0.1502, 0.1507, 
            0.1311, 0.1547, 0.1418, 0.1370, 0.1393, 0.1272, 0.1330, 0.1194, 0.1121, 0.1187, 
            0.1211, 0.1181, 0.1187, 0.1144, 0.1095, 0.1055, 0.1102, 0.1101, 0.1142, 0.1038, 
            0.1049, 0.1078, 0.1032, 0.1103, 0.1062, 0.1083, 0.1061, 0.0995, 0.1049, 0.0997, 
            0.0997, 0.0990, 0.0970, 0.0979, 0.0980, 0.0997, 0.0972, 0.0940, 0.0961, 0.0956]

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss Attention U Net features [32, 64, 128, 256] Fold 2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_fold1.png')

# %%
train_loss = [0.3684, 0.3067, 0.2855, 0.2767, 0.2759, 0.2712, 0.2633, 0.2650, 0.2540, 0.2578, 
              0.2498, 0.2459, 0.2424, 0.2396, 0.2329, 0.2314, 0.2292, 0.2267, 0.2205, 0.2196, 
              0.2261, 0.2135, 0.2151, 0.2101, 0.2106, 0.2041, 0.2036, 0.2016, 0.2061, 0.2042, 
              0.2044, 0.1916, 0.1883, 0.1893, 0.1868, 0.1800, 0.1795, 0.1856, 0.1819, 0.1839, 
              0.1794, 0.1756, 0.1724, 0.1716, 0.1727, 0.1677, 0.1699, 0.1723, 0.1704, 0.1662]
val_loss = [0.2167, 0.1988, 0.1951, 0.2309, 0.1934, 0.1700, 0.1660, 0.1529, 0.1476, 0.1442, 
            0.1433, 0.1330, 0.1415, 0.1323, 0.1375, 0.1291, 0.1340, 0.1365, 0.1271, 0.1240, 
            0.1284, 0.1132, 0.1459, 0.1044, 0.1121, 0.1125, 0.1037, 0.1066, 0.1122, 0.1248, 
            0.1129, 0.1029, 0.0990, 0.0999, 0.0965, 0.0908, 0.0891, 0.0952, 0.0994, 0.0950, 
            0.0942, 0.0915, 0.0913, 0.0909, 0.0901, 0.0893, 0.0937, 0.0911, 0.0903, 0.0888]


epochs = np.arange(1, 51)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss Attention U Net features [32, 64, 128, 256] Fold 3')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_fold1.png')

# %%
train_loss = [0.3705, 0.3039, 0.2819, 0.2764, 0.2693, 0.2612, 0.2545, 0.2516, 0.2471, 0.2449, 
              0.2386, 0.2383, 0.2326, 0.2353, 0.2291, 0.2254, 0.2270, 0.2219, 0.2109, 0.2099, 
              0.2157, 0.2082, 0.2103, 0.2053, 0.2067, 0.2007, 0.2066, 0.2012, 0.1998, 0.1955, 
              0.1866, 0.1901, 0.1856, 0.1854, 0.1861, 0.1830, 0.1840, 0.1772, 0.1775, 0.1721, 
              0.1755, 0.1705, 0.1728, 0.1739, 0.1709, 0.1683, 0.1738, 0.1693, 0.1687, 0.1686]
val_loss = [0.2140, 0.2201, 0.1910, 0.3527, 0.2037, 0.1741, 0.1631, 0.1771, 0.2024, 0.1700, 
            0.1522, 0.1575, 0.1532, 0.1493, 0.1707, 0.1417, 0.1511, 0.1353, 0.1374, 0.1262, 
            0.1534, 0.1246, 0.1336, 0.1307, 0.1203, 0.1108, 0.1213, 0.1200, 0.1420, 0.1177, 
            0.1119, 0.1063, 0.1039, 0.1063, 0.1083, 0.1079, 0.1108, 0.0991, 0.0999, 0.1015, 
            0.1056, 0.0958, 0.1054, 0.1050, 0.0966, 0.0934, 0.0968, 0.0934, 0.0962, 0.0914]

epochs = np.arange(1, 51)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss Attention U Net features [32, 64, 128, 256] Fold 4')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_fold1.png')

# %%
train_loss = [0.3591, 0.2998, 0.2913, 0.2708, 0.2743, 0.2605, 0.2626, 0.2573, 0.2483, 0.2356, 
              0.2386, 0.2286, 0.2316, 0.2284, 0.2241, 0.2250, 0.2226, 0.2161, 0.2195, 0.2160, 
              0.2194, 0.2088, 0.2088, 0.2052, 0.2016, 0.1999, 0.1977, 0.1934, 0.1962, 0.1941, 
              0.1916, 0.1943, 0.1898, 0.1926, 0.1926, 0.1909, 0.1893, 0.1887, 0.1879, 0.1930, 
              0.1924, 0.1902, 0.1867, 0.1846, 0.1878, 0.1848, 0.1828, 0.1850, 0.1820, 0.1802]
val_loss = [0.1977, 0.2531, 0.1614, 0.1772, 0.1454, 0.1673, 0.1545, 0.1907, 0.1515, 0.1497, 
            0.1400, 0.1419, 0.1368, 0.1317, 0.1163, 0.1126, 0.1114, 0.1306, 0.1324, 0.1148, 
            0.1323, 0.1064, 0.1150, 0.1066, 0.1163, 0.1101, 0.1028, 0.0999, 0.1016, 0.1080, 
            0.1023, 0.0988, 0.0984, 0.1055, 0.1012, 0.0974, 0.1009, 0.0960, 0.0979, 0.1020, 
            0.0986, 0.0949, 0.0980, 0.0971, 0.0934, 0.0953, 0.0945, 0.0993, 0.0977, 0.0931]

epochs = np.arange(1, 51)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b-', label='Train Loss')
plt.plot(epochs, val_loss, 'r-', label='Test Loss')
plt.title('Train and Test Loss Attention U Net features [32, 64, 128, 256] Fold 5')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('loss_plot_fold1.png')
