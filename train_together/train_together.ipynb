# %%
import pandas as pd
from pathlib import Path
image_folder = Path(r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\AND_result_fold2")
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"
label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label = {}
for item in range(len(label_df['name'])):
    label[int(label_df['name'][item].split('.')[0])] = label_df['grade'][item]
    
new_label = {}
for key, value in label.items():
    if key < 359:
        if value == 0:
            new_label[key] = value
    else:
        new_label[key] = value

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
from sklearn.model_selection import StratifiedKFold
image_dir = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\train_together\images"
image_paths = []
labels = []

for img_id, lbl in new_label.items():
    filename = f"{img_id}.jpg"
    full_path = os.path.join(image_dir, filename)
    if os.path.exists(full_path):
        image_paths.append(full_path)
        labels.append(lbl)
    else:
        print(f"Warning: {full_path} not found!")

image_transforms = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    # اگر لازم داری نرمال سازی رنگ‌ها رو اضافه کن
])

mask_transforms = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: (x > 0.5).float())  # همین خط رو اضافه کن
])

# تعریف کلاس Dataset
class CorneaDataset(torch.utils.data.Dataset):
    def __init__(self, image_dir, mask_dir, label_dict, transform=None, mask_transform=None):
        """
        image_dir: مسیر تصاویر RGB (jpg/png)
        mask_dir: مسیر ماسک‌ها (png)
        label_dict: دیکشنری {image_id: class_label}
        transform: تبدیل‌های تصاویر (Resize, ToTensor و ...)
        mask_transform: تبدیل‌های ماسک (Resize, ToTensor و ...)
        """
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.label_dict = label_dict
        self.transform = transform
        self.mask_transform = mask_transform
        
        self.image_names = sorted([f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.png'))])
        
    def __len__(self):
        return len(self.image_names)
    
    def __getitem__(self, idx):
        img_name = self.image_names[idx]
        img_id = int(os.path.splitext(img_name)[0])
        
        # بارگذاری تصویر
        img_path = os.path.join(self.image_dir, img_name)
        image = Image.open(img_path).convert("RGB")
        
        # بارگذاری ماسک
        mask_name = os.path.splitext(img_name)[0] + '.png'  # فرض شده ماسک با همون id ولی پسوند png
        mask_path = os.path.join(self.mask_dir, mask_name)
        mask = Image.open(mask_path).convert("L")  # ماسک سیاه سفید
        
        # اعمال تبدیل‌ها
        if self.transform:
            image = self.transform(image)
        if self.mask_transform:
            mask = self.mask_transform(mask)
        
        # گرفتن label کلاس
        label = self.label_dict.get(img_id, 0)  # اگر نبود 0 فرض کن
        
        return image, label, mask
    
image_dir = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\train_together\images"
mask_dir = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\train_together\ulcer_images"
# ساخت Dataset کامل
full_dataset = CorneaDataset(image_dir, mask_dir, new_label, image_transforms, mask_transforms)

# تعریف Stratified K-Fold
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_indices = list(kf.split(image_paths, labels))

# مثلاً دسترسی به fold اول:
train_idx, val_idx = fold_indices[0]



train_dataset = CorneaDataset(image_dir=image_dir,
                             mask_dir=mask_dir,
                             label_dict=new_label,  # دیکشنری label که قبلا ساختی
                             transform=image_transforms,
                             mask_transform=mask_transforms)

val_dataset = Subset(full_dataset, val_idx)

# ساخت DataLoader ها

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=0)

print(f"Train samples: {len(train_dataset)}, Val samples: {len(val_dataset)}")
# Out:
# Train samples: 390, Val samples: 78

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# تعریف Attention Gate
class AttentionGate(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super(AttentionGate, self).__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        self.relu = nn.ReLU(inplace=True)
    
    def forward(self, g, x):
        # g: از upsampling، x: از downsampling (skip connection)
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi  # وزن دهی به x با نقشه توجه

# تعریف Double Convolution Block
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )
    def forward(self, x):
        return self.conv(x)

# تعریف Attention U-Net کامل
class AttentionUNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super(AttentionUNet, self).__init__()
        # Downsampling
        self.dconv_down1 = DoubleConv(in_channels, 64)
        self.dconv_down2 = DoubleConv(64, 128)
        self.dconv_down3 = DoubleConv(128, 256)
        self.dconv_down4 = DoubleConv(256, 512)
        
        self.maxpool = nn.MaxPool2d(2)
        
        # Bottleneck
        self.bottleneck = DoubleConv(512, 1024)
        
        # Upsampling
        self.up_trans_4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.att4 = AttentionGate(F_g=512, F_l=512, F_int=256)
        self.up_conv_4 = DoubleConv(1024, 512)
        
        self.up_trans_3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.att3 = AttentionGate(F_g=256, F_l=256, F_int=128)
        self.up_conv_3 = DoubleConv(512, 256)
        
        self.up_trans_2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.att2 = AttentionGate(F_g=128, F_l=128, F_int=64)
        self.up_conv_2 = DoubleConv(256, 128)
        
        self.up_trans_1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.att1 = AttentionGate(F_g=64, F_l=64, F_int=32)
        self.up_conv_1 = DoubleConv(128, 64)
        
        # لایه نهایی segmentation
        self.out = nn.Conv2d(64, out_channels, kernel_size=1)
    
    def forward(self, x):
        # Downsampling path
        x1 = self.dconv_down1(x)
        x2 = self.dconv_down2(self.maxpool(x1))
        x3 = self.dconv_down3(self.maxpool(x2))
        x4 = self.dconv_down4(self.maxpool(x3))
        
        # Bottleneck
        x5 = self.bottleneck(self.maxpool(x4))
        
        # Upsampling + Attention + Padding + Concat + DoubleConv
        
        d4 = self.up_trans_4(x5)
        x4 = self.att4(g=d4, x=x4)
        diffY = x4.size(2) - d4.size(2)
        diffX = x4.size(3) - d4.size(3)
        d4 = F.pad(d4, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        d4 = torch.cat((x4, d4), dim=1)
        d4 = self.up_conv_4(d4)
        
        d3 = self.up_trans_3(d4)
        x3 = self.att3(g=d3, x=x3)
        diffY = x3.size(2) - d3.size(2)
        diffX = x3.size(3) - d3.size(3)
        d3 = F.pad(d3, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        d3 = torch.cat((x3, d3), dim=1)
        d3 = self.up_conv_3(d3)
        
        d2 = self.up_trans_2(d3)
        x2 = self.att2(g=d2, x=x2)
        diffY = x2.size(2) - d2.size(2)
        diffX = x2.size(3) - d2.size(3)
        d2 = F.pad(d2, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        d2 = torch.cat((x2, d2), dim=1)
        d2 = self.up_conv_2(d2)
        
        d1 = self.up_trans_1(d2)
        x1 = self.att1(g=d1, x=x1)
        diffY = x1.size(2) - d1.size(2)
        diffX = x1.size(3) - d1.size(3)
        d1 = F.pad(d1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        d1 = torch.cat((x1, d1), dim=1)
        d1 = self.up_conv_1(d1)
        
        feature_map = d1
        out = self.out(d1)
        return out, feature_map


class ClassifierCNNMLP(nn.Module):
    def __init__(self, in_channels=64, num_classes=5):  
        super(ClassifierCNNMLP, self).__init__()
        # توجه کن که in_channels برابر با تعداد channel خروجی لایه یکی مونده به آخر upsampling تو U-Net است (مثلا 64)
        
        self.cnn_layers = nn.Sequential(
            nn.Conv2d(in_channels, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),  # کاهش سایز
        
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d((4, 4))  # کاهش به 4x4
        )
        
        self.mlp = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256*4*4, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(512, num_classes)
        )
    
    def forward(self, x):
        x = self.cnn_layers(x)
        x = self.mlp(x)
        return x

# %%
import torch
import torch.nn as nn
# 
# def train_one_epoch(unet, classifier, device, train_loader, optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls):
#     unet.train()
#     classifier.train()
#     
#     total_loss_seg = 0.0
#     total_loss_cls = 0.0
#     
#     for images, labels in train_loader:
#         images = images.to(device)
#         labels = labels.to(device)
#         
#         # ---------------------------
#         # مرحله اول: آموزش Classifier با Feature Map
#         # ---------------------------
#         
#         # فریز وزن‌های U-Net
#         for param in unet.parameters():
#             param.requires_grad = False
#         # فعال‌کردن وزن‌های Classifier
#         for param in classifier.parameters():
#             param.requires_grad = True
#         
#         optimizer_classifier.zero_grad()
#         
#         # فوروارد U-Net برای گرفتن feature map
#         with torch.no_grad():
#             _, feature_map = unet(images)
#         
#         # فوروارد Classifier
#         preds_cls = classifier(feature_map)
#         
#         loss_cls = criterion_cls(preds_cls, labels)
#         loss_cls.backward()
#         optimizer_classifier.step()
#         
#         
#         # ---------------------------
#         # مرحله دوم: آموزش U-Net با ماسک Segmentation
#         # ---------------------------
#         
#         # فعال‌کردن وزن‌های U-Net
#         for param in unet.parameters():
#             param.requires_grad = True
#         # فریز وزن‌های Classifier
#         for param in classifier.parameters():
#             param.requires_grad = False
#         
#         optimizer_unet.zero_grad()
#         
#         # فوروارد U-Net کامل (ماسک + feature map)
#         preds_seg, _ = unet(images)
#         
#         # اینجا فرض بر اینه که ماسک‌ها (ground truth) هم باید باشن
#         # اما در دیتاست فعلی ما فقط کلاس داریم، پس باید ماسک‌ها رو هم آماده کرده باشی
#         # فرض می‌کنیم که train_loader ماسک segmentation رو هم همراه تصویر میده:
#         # (images, labels, masks)
#         # پس باید دیتاست و لودر رو بروز کنیم؛ اگر نه این بخش رو باید جداگانه مدیریت کنی
#         
#         # اینجا چون گفتی فقط label داری و ماسک داری، فرض میکنیم در دیتاست ماسک هم هست
#         # مثال:
#         # images, labels, masks = ...
#         
#         # برای نمونه، من اینجا ماسک‌ها رو جایگزین None میذارم، باید اصلاح کنی
#         masks = None  # <-- این خط رو با ماسک‌های واقعی جایگزین کن
#         
#         if masks is not None:
#             masks = masks.to(device)
#             loss_seg = criterion_seg(preds_seg, masks)
#             loss_seg.backward()
#             optimizer_unet.step()
#             total_loss_seg += loss_seg.item()
#         else:
#             # اگر ماسک نداری، فقط optimizer رو صفر کن و پیش برو
#             optimizer_unet.step()
#         
#         total_loss_cls += loss_cls.item()
#     
#     return total_loss_seg / len(train_loader), total_loss_cls / len(train_loader)


def validate_one_epoch(unet, classifier, device, val_loader, criterion_seg, criterion_cls):
    unet.eval()
    classifier.eval()
    
    total_loss_seg = 0.0
    total_loss_cls = 0.0
    
    all_preds_cls = []
    all_labels_cls = []
    
    all_preds_seg = []
    all_labels_seg = []
    
    with torch.no_grad():
        for batch in val_loader:
            images, labels, masks = batch
            
            images = images.to(device)
            labels = labels.to(device)
            masks = masks.to(device)
            
            preds_seg, feature_map = unet(images)
            preds_cls = classifier(feature_map)
            
            loss_seg = criterion_seg(preds_seg, masks)
            loss_cls = criterion_cls(preds_cls, labels)
            
            total_loss_seg += loss_seg.item()
            total_loss_cls += loss_cls.item()
            
            # ذخیره نتایج classification
            all_preds_cls.append(preds_cls.detach().cpu())
            all_labels_cls.append(labels.detach().cpu())
            
            # ذخیره نتایج segmentation
            all_preds_seg.append(torch.sigmoid(preds_seg).detach().cpu())
            all_labels_seg.append(masks.detach().cpu())
    
    avg_loss_seg = total_loss_seg / len(val_loader)
    avg_loss_cls = total_loss_cls / len(val_loader)
    
    all_preds_cls = torch.cat(all_preds_cls)
    all_labels_cls = torch.cat(all_labels_cls)
    
    all_preds_seg = torch.cat(all_preds_seg)
    all_labels_seg = torch.cat(all_labels_seg)
    
    return avg_loss_seg, avg_loss_cls, all_preds_seg, all_labels_seg, all_preds_cls, all_labels_cls

# %%
import torch
import torch.nn as nn

# تابع برای فریز و آنفریز کردن وزن‌ها
def set_requires_grad(model, requires_grad):
    for param in model.parameters():
        param.requires_grad = requires_grad

# یک epoch آموزش (train)
def train_one_epoch(unet, classifier, device, train_loader, optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls):
    unet.train()
    classifier.train()
    
    total_loss_seg = 0.0
    total_loss_cls = 0.0
    
    # لیست‌هایی برای ذخیره پیش‌بینی‌ها و لیبل‌ها (برای محاسبه معیارها)
    all_preds_cls = []
    all_labels_cls = []
    
    all_preds_seg = []
    all_labels_seg = []
    
    for batch in train_loader:
        images, labels, masks = batch
        
        images = images.to(device)
        labels = labels.to(device)
        masks = masks.to(device)
        
        # --- آموزش Classifier ---
        set_requires_grad(unet, False)
        set_requires_grad(classifier, True)
        
        optimizer_classifier.zero_grad()
        
        with torch.no_grad():
            _, feature_map = unet(images)
        
        preds_cls = classifier(feature_map)  # خروجی classifier (logits)
        loss_cls = criterion_cls(preds_cls, labels)
        loss_cls.backward()
        optimizer_classifier.step()
        
        total_loss_cls += loss_cls.item()
        
        # ذخیره نتایج classification
        all_preds_cls.append(preds_cls.detach().cpu())
        all_labels_cls.append(labels.detach().cpu())
        
        # --- آموزش U-Net ---
        set_requires_grad(unet, True)
        set_requires_grad(classifier, False)
        
        optimizer_unet.zero_grad()
        
        preds_seg, _ = unet(images)  # خروجی segmentation (logits)
        loss_seg = criterion_seg(preds_seg, masks)
        loss_seg.backward()
        optimizer_unet.step()
        
        total_loss_seg += loss_seg.item()
        
        # ذخیره نتایج segmentation (قبل از تابع فعالسازی)
        all_preds_seg.append(torch.sigmoid(preds_seg).detach().cpu())  # تبدیل logits به احتمالات
        all_labels_seg.append(masks.detach().cpu())
    
    avg_loss_seg = total_loss_seg / len(train_loader)
    avg_loss_cls = total_loss_cls / len(train_loader)
    
    # concat همه batch ها
    all_preds_cls = torch.cat(all_preds_cls)
    all_labels_cls = torch.cat(all_labels_cls)
    
    all_preds_seg = torch.cat(all_preds_seg)
    all_labels_seg = torch.cat(all_labels_seg)
    
    return avg_loss_seg, avg_loss_cls, all_preds_seg, all_labels_seg, all_preds_cls, all_labels_cls


# یک epoch ارزیابی (validation)
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix

# def calculate_classification_metrics(preds_cls, labels_cls):
#     preds_labels = preds_cls.argmax(dim=1).numpy()
#     true_labels = labels_cls.numpy()
# 
#     acc = accuracy_score(true_labels, preds_labels)
#     f1 = f1_score(true_labels, preds_labels, average='weighted')
#     sens = recall_score(true_labels, preds_labels, average='weighted')  # sensitivity = recall
#     spec = None  # specificity را باید دستی محاسبه کنیم اگر دوتایی باشه، اینجا میشه اضافه کرد
#     return acc, f1, sens, spec
def calculate_classification_metrics(preds_cls, labels_cls):
    from sklearn.metrics import accuracy_score, balanced_accuracy_score, f1_score, recall_score, precision_score, confusion_matrix
    preds_labels = preds_cls.argmax(dim=1).numpy()
    true_labels = labels_cls.numpy()

    acc = accuracy_score(true_labels, preds_labels)
    balanced_acc = balanced_accuracy_score(true_labels, preds_labels)
    f1 = f1_score(true_labels, preds_labels, average='weighted')
    sens = recall_score(true_labels, preds_labels, average='weighted')
    
    # Specificity برای چندکلاسه
    cm = confusion_matrix(true_labels, preds_labels)
    tn = []
    fp = []
    for i in range(cm.shape[0]):
        temp_cm = cm.copy()
        temp_cm[i, :] = 0
        temp_cm[:, i] = 0
        tn.append(temp_cm.sum())
        fp.append(cm[:, i].sum() - cm[i,i])
    spec = sum([tn[i]/(tn[i]+fp[i]+1e-6) for i in range(len(tn))])/len(tn)
    
    return acc, balanced_acc, f1, sens, spec


def dice_coefficient(preds, labels, threshold=0.5):
    preds_bin = (preds > threshold).float()
    intersection = (preds_bin * labels).sum(dim=(1,2,3))
    union = preds_bin.sum(dim=(1,2,3)) + labels.sum(dim=(1,2,3))
    dice = (2*intersection + 1e-6)/(union + 1e-6)
    return dice.mean().item()

def iou_score(preds, labels, threshold=0.5):
    preds_bin = (preds > threshold).float()
    intersection = (preds_bin * labels).sum(dim=(1,2,3))
    union = preds_bin.sum(dim=(1,2,3)) + labels.sum(dim=(1,2,3)) - intersection
    iou = (intersection + 1e-6)/(union + 1e-6)
    return iou.mean().item()

def precision_score_seg(preds, labels, threshold=0.5):
    preds_bin = (preds > threshold).float()
    tp = (preds_bin * labels).sum(dim=(1,2,3))
    fp = (preds_bin * (1-labels)).sum(dim=(1,2,3))
    precision = (tp + 1e-6)/(tp + fp + 1e-6)
    return precision.mean().item()

def recall_score_seg(preds, labels, threshold=0.5):
    preds_bin = (preds > threshold).float()
    tp = (preds_bin * labels).sum(dim=(1,2,3))
    fn = ((1-preds_bin) * labels).sum(dim=(1,2,3))
    recall = (tp + 1e-6)/(tp + fn + 1e-6)
    return recall.mean().item()

# 
# def train_loop(unet, classifier, device, train_loader, val_loader, optimizer_unet, optimizer_classifier,
#                criterion_seg, criterion_cls, epochs):
#     
#     train_losses_seg = []
#     train_losses_cls = []
#     val_losses_seg = []
#     val_losses_cls = []
#     
#     for epoch in range(1, epochs+1):
#         # train_loss_seg, train_loss_cls = train_one_epoch(unet, classifier, device, train_loader,
#         #                                                  optimizer_unet, optimizer_classifier,
#         #                                                  criterion_seg, criterion_cls)
#         # train_loss_seg, train_loss_cls, train_preds_seg, train_labels_seg, train_preds_cls, train_labels_cls = train_one_epoch(
#         #     unet, classifier, device, train_loader,
#         #     optimizer_unet, optimizer_classifier,
#         #     criterion_seg, criterion_cls)
#         train_loss_seg, train_loss_cls, train_preds_seg, train_labels_seg, train_preds_cls, train_labels_cls = train_one_epoch(
#                 unet, classifier, device, train_loader,
#                 optimizer_unet, optimizer_classifier,
#                 criterion_seg, criterion_cls)
#         
#         # val_loss_seg, val_loss_cls, val_preds_seg, val_labels_seg, val_preds_cls, val_labels_cls = validate_one_epoch(
#         #     unet, classifier, device, val_loader, criterion_seg, criterion_cls)
#         val_loss_seg, val_loss_cls, val_preds_seg, val_labels_seg, val_preds_cls, val_labels_cls = validate_one_epoch(
#             unet, classifier, device, val_loader, criterion_seg, criterion_cls)
#         
#         train_losses_seg.append(train_loss_seg)
#         train_losses_cls.append(train_loss_cls)
#         val_losses_seg.append(val_loss_seg)
#         val_losses_cls.append(val_loss_cls)
#         
#         # محاسبه معیارهای classification برای validation
#         acc, f1, sens, spec = calculate_classification_metrics(val_preds_cls, val_labels_cls)
#         
#         print(f"Epoch {epoch}/{epochs} | "
#               f"Train Seg Loss: {train_loss_seg:.4f} | Train Cls Loss: {train_loss_cls:.4f} | "
#               f"Val Seg Loss: {val_loss_seg:.4f} | Val Cls Loss: {val_loss_cls:.4f}")
#         print(f"Validation Classification Metrics -> Accuracy: {acc:.4f}, F1: {f1:.4f}, Sensitivity: {sens:.4f}")
#         
#         # اینجا میتونی معیارهای segmentation (مثل dice و specificity) هم اضافه کنی اگر تابعشون رو داری
#         
#     # رسم نمودار Loss
#     epochs_range = range(1, epochs+1)
#     plt.figure(figsize=(12,5))
#     
#     plt.subplot(1,2,1)
#     plt.plot(epochs_range, train_losses_seg, label='Train Seg Loss')
#     plt.plot(epochs_range, val_losses_seg, label='Val Seg Loss')
#     plt.legend()
#     plt.title('Segmentation Loss')
#     
#     plt.subplot(1,2,2)
#     plt.plot(epochs_range, train_losses_cls, label='Train Cls Loss')
#     plt.plot(epochs_range, val_losses_cls, label='Val Cls Loss')
#     plt.legend()
#     plt.title('Classification Loss')
#     
#     plt.show()

def train_loop(unet, classifier, device, train_loader, val_loader, optimizer_unet, optimizer_classifier,
               criterion_seg, criterion_cls, epochs, patience=5):
    
    train_losses_seg = []
    val_losses_seg = []
    train_losses_cls = []
    val_losses_cls = []
    
    best_val_metric = -1  # برای accuracy که هرچه بیشتر بهتر
    patience_counter = 0
    
    for epoch in range(1, epochs+1):
        train_loss_seg, train_loss_cls, train_preds_seg, train_labels_seg, train_preds_cls, train_labels_cls = train_one_epoch(
            unet, classifier, device, train_loader,
            optimizer_unet, optimizer_classifier,
            criterion_seg, criterion_cls)
        
        val_loss_seg, val_loss_cls, val_preds_seg, val_labels_seg, val_preds_cls, val_labels_cls = validate_one_epoch(
            unet, classifier, device, val_loader, criterion_seg, criterion_cls)
        
        # --- محاسبه متریک‌ها ---
        train_acc, train_bal_acc, train_f1, train_sens, train_spec = calculate_classification_metrics(train_preds_cls, train_labels_cls)
        val_acc, val_bal_acc, val_f1, val_sens, val_spec = calculate_classification_metrics(val_preds_cls, val_labels_cls)
        
        train_dice = dice_coefficient(train_preds_seg, train_labels_seg)
        train_iou = iou_score(train_preds_seg, train_labels_seg)
        train_prec = precision_score_seg(train_preds_seg, train_labels_seg)
        train_rec = recall_score_seg(train_preds_seg, train_labels_seg)
        
        val_dice = dice_coefficient(val_preds_seg, val_labels_seg)
        val_iou = iou_score(val_preds_seg, val_labels_seg)
        val_prec = precision_score_seg(val_preds_seg, val_labels_seg)
        val_rec = recall_score_seg(val_preds_seg, val_labels_seg)
        
        # --- چاپ نتایج ---
        print(f"\nEpoch {epoch}/{epochs}")
        print(f"Train Losses -> Seg: {train_loss_seg:.4f}, Cls: {train_loss_cls:.4f}")
        print(f"Val Losses   -> Seg: {val_loss_seg:.4f}, Cls: {val_loss_cls:.4f}")
        print(f"Train Classification -> Acc: {train_acc:.4f}, Bal Acc: {train_bal_acc:.4f}, F1: {train_f1:.4f}, Sens: {train_sens:.4f}, Spec: {train_spec:.4f}")
        print(f"Val Classification   -> Acc: {val_acc:.4f}, Bal Acc: {val_bal_acc:.4f}, F1: {val_f1:.4f}, Sens: {val_sens:.4f}, Spec: {val_spec:.4f}")
        print(f"Train Segmentation -> Dice: {train_dice:.4f}, IoU: {train_iou:.4f}, Precision: {train_prec:.4f}, Recall: {train_rec:.4f}")
        print(f"Val Segmentation   -> Dice: {val_dice:.4f}, IoU: {val_iou:.4f}, Precision: {val_prec:.4f}, Recall: {val_rec:.4f}")
        
        train_losses_seg.append(train_loss_seg)
        val_losses_seg.append(val_loss_seg)
        train_losses_cls.append(train_loss_cls)
        val_losses_cls.append(val_loss_cls)
        
        # --- Early Stopping روی Accuracy validation (تغییر اینجا) ---
        if val_acc > best_val_metric:
            best_val_metric = val_acc
            patience_counter = 0
            print(f"🎯 New best accuracy: {val_acc:.4f}")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"⏹️ Early stopping at epoch {epoch}!")
                break

    # --- نمایش ۵ تصویر نمونه train و val ---
    def show_sample_images(loader, unet, classifier, device, num_samples=5, dataset_type="Train", class_names=None):
        unet.eval()
        classifier.eval()
        samples_shown = 0
        
        with torch.no_grad():
            for batch in loader:
                images, labels, masks = batch
                images = images.to(device)
                masks = masks.to(device)
                labels = labels.to(device)
                
                preds_seg, feature_map = unet(images)
                preds_seg = torch.sigmoid(preds_seg)  # تبدیل logits به probability
                preds_cls = classifier(feature_map)
                preds_cls_labels = preds_cls.argmax(dim=1)
                
                for i in range(images.size(0)):
                    if samples_shown >= num_samples:
                        return
                    
                    image = images[i].cpu()
                    mask_true = masks[i].cpu()
                    mask_pred = preds_seg[i].cpu()
                    true_label = labels[i].cpu().item()
                    pred_label = preds_cls_labels[i].cpu().item()
                    
                    # 🔥 تبدیل ماسک پیش‌بینی شده به باینری
                    mask_pred_binary = (mask_pred > 0.5).float()  # آستانه‌گذاری 0.5
                    
                    # استفاده از اسم کلاس
                    true_label_str = class_names[true_label] if class_names else str(true_label)
                    pred_label_str = class_names[pred_label] if class_names else str(pred_label)
                    
                    # اصلاح شکل‌ها
                    if image.shape[0] == 3:
                        image = image.permute(1, 2, 0)
                    if mask_true.ndim == 3 and mask_true.shape[0] == 1:
                        mask_true = mask_true.squeeze(0)
                    if mask_pred_binary.ndim == 3 and mask_pred_binary.shape[0] == 1:
                        mask_pred_binary = mask_pred_binary.squeeze(0)
                    
                    plt.figure(figsize=(12, 4))
                    
                    plt.subplot(1, 3, 1)
                    plt.imshow(image)
                    plt.title(f"Image\nTrue: {true_label_str}, Pred: {pred_label_str}")
                    plt.axis('off')
                    
                    plt.subplot(1, 3, 2)
                    plt.imshow(mask_true, cmap='gray', vmin=0, vmax=1)
                    plt.title("GT Mask (0=زخم, 1=سالم)")
                    plt.axis('off')
                    
                    plt.subplot(1, 3, 3)
                    plt.imshow(mask_pred_binary, cmap='gray', vmin=0, vmax=1)  # 🔥 نمایش باینری
                    plt.title("Pred Mask (باینری شده)")
                    plt.axis('off')
                    
                    plt.suptitle(f"{dataset_type} Sample - True: {true_label_str}, Pred: {pred_label_str}", 
                               fontsize=14, fontweight='bold')
                    plt.show()
                    
                    samples_shown += 1
    # def show_sample_images(loader, num_samples=5, dataset_type="Train"):
    #     unet.eval()
    #     samples_shown = 0
    # 
    #     with torch.no_grad():
    #         for batch in loader:
    #             images, labels, masks = batch
    #             images = images.to(device)
    #             masks = masks.to(device)
    # 
    #             preds_seg, _ = unet(images)
    #             preds_seg = torch.sigmoid(preds_seg)
    # 
    #             for i in range(images.size(0)):
    #                 if samples_shown >= num_samples:
    #                     return
    # 
    #                 image = images[i].cpu()
    #                 mask_true = masks[i].cpu()
    #                 mask_pred = preds_seg[i].cpu()
    # 
    #                 # --- اصلاح شکل‌ها ---
    #                 if image.shape[0] == 3:  # RGB
    #                     image = image.permute(1, 2, 0)
    #                 if mask_true.ndim == 3 and mask_true.shape[0] == 1:
    #                     mask_true = mask_true.squeeze(0)
    #                 if mask_pred.ndim == 3 and mask_pred.shape[0] == 1:
    #                     mask_pred = mask_pred.squeeze(0)
    # 
    #                 plt.figure(figsize=(12,4))
    # 
    #                 plt.subplot(1,3,1)
    #                 plt.imshow(image)
    #                 plt.title("Image")
    #                 plt.axis('off')
    # 
    #                 plt.subplot(1,3,2)
    #                 plt.imshow(mask_true, cmap='gray')
    #                 plt.title("GT Mask")
    #                 plt.axis('off')
    # 
    #                 plt.subplot(1,3,3)
    #                 plt.imshow(mask_pred, cmap='gray')
    #                 plt.title("Pred Mask")
    #                 plt.axis('off')
    # 
    #                 plt.show()
    # 
    #                 samples_shown += 1
    
    # نمایش ۵ تصویر train و ۵ تصویر val
    show_sample_images(train_loader, num_samples=5, dataset_type="Train")
    show_sample_images(val_loader, num_samples=5, dataset_type="Validation")
    
    
    return train_losses_seg, val_losses_seg, train_losses_cls, val_losses_cls, val_preds_cls, val_labels_cls, train_preds_cls, train_labels_cls, val_preds_seg, val_labels_seg
    
    
import seaborn as sns
def plot_confusion_matrix(preds_cls, labels_cls, class_names=None, dataset_type="Validation"):
    """
    preds_cls: tensor خروجی classifier (logits)
    labels_cls: tensor labels واقعی
    class_names: لیست اسم کلاس‌ها
    """
    preds_labels = preds_cls.argmax(dim=1).cpu().numpy()
    true_labels = labels_cls.cpu().numpy()
    
    cm = confusion_matrix(true_labels, preds_labels)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"{dataset_type} Confusion Matrix")
    plt.show()


def plot_losses(train_losses_seg, val_losses_seg, train_losses_cls, val_losses_cls):
    epochs = range(1, len(train_losses_seg)+1)

    plt.figure(figsize=(12,5))

    # Segmentation Loss
    plt.subplot(1,2,1)
    plt.plot(epochs, train_losses_seg, label='Train Seg Loss')
    plt.plot(epochs, val_losses_seg, label='Val Seg Loss')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Segmentation Loss")
    plt.legend()

    # Classification Loss
    plt.subplot(1,2,2)
    plt.plot(epochs, train_losses_cls, label='Train Cls Loss')
    plt.plot(epochs, val_losses_cls, label='Val Cls Loss')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Classification Loss")
    plt.legend()

    plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

unet = AttentionUNet(in_channels=3, out_channels=1).to(device)
classifier = ClassifierCNNMLP(in_channels=64, num_classes=5).to(device)

criterion_seg = nn.BCEWithLogitsLoss()
criterion_cls = nn.CrossEntropyLoss()

optimizer_unet = optim.Adam(unet.parameters(), lr=1e-4)
optimizer_classifier = optim.Adam(classifier.parameters(), lr=1e-4)

num_epochs = 20  

train_loop(unet, classifier, device, train_loader, val_loader, 
           optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls, num_epochs)
# Out:
# Epoch 1/20 | Train Seg Loss: 0.5079 | Train Cls Loss: 1.5202 | Val Seg Loss: 0.4021 | Val Cls Loss: 1.4517
# Validation Classification Metrics -> Accuracy: 0.3590, F1: 0.2564, Sensitivity: 0.3590
# Epoch 2/20 | Train Seg Loss: 0.3626 | Train Cls Loss: 1.4826 | Val Seg Loss: 0.3664 | Val Cls Loss: 1.5937
# Validation Classification Metrics -> Accuracy: 0.3205, F1: 0.3048, Sensitivity: 0.3205
# Epoch 3/20 | Train Seg Loss: 0.3322 | Train Cls Loss: 1.4480 | Val Seg Loss: 0.3162 | Val Cls Loss: 1.4232
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3388, Sensitivity: 0.3974
# Epoch 4/20 | Train Seg Loss: 0.3104 | Train Cls Loss: 1.4279 | Val Seg Loss: 0.2980 | Val Cls Loss: 1.4222
# Validation Classification Metrics -> Accuracy: 0.3590, F1: 0.2719, Sensitivity: 0.3590
# Epoch 5/20 | Train Seg Loss: 0.2979 | Train Cls Loss: 1.4203 | Val Seg Loss: 0.2829 | Val Cls Loss: 1.3764
# Validation Classification Metrics -> Accuracy: 0.3590, F1: 0.3319, Sensitivity: 0.3590
# Epoch 6/20 | Train Seg Loss: 0.2835 | Train Cls Loss: 1.3837 | Val Seg Loss: 0.2646 | Val Cls Loss: 1.3457
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3597, Sensitivity: 0.3974
# Epoch 7/20 | Train Seg Loss: 0.2705 | Train Cls Loss: 1.3753 | Val Seg Loss: 0.2547 | Val Cls Loss: 1.3548
# Validation Classification Metrics -> Accuracy: 0.3590, F1: 0.3371, Sensitivity: 0.3590
# Epoch 8/20 | Train Seg Loss: 0.2596 | Train Cls Loss: 1.3697 | Val Seg Loss: 0.2514 | Val Cls Loss: 1.3116
# Validation Classification Metrics -> Accuracy: 0.3846, F1: 0.3533, Sensitivity: 0.3846
# Epoch 9/20 | Train Seg Loss: 0.2454 | Train Cls Loss: 1.3331 | Val Seg Loss: 0.2316 | Val Cls Loss: 1.2951
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.4052, Sensitivity: 0.4231
# Epoch 10/20 | Train Seg Loss: 0.2352 | Train Cls Loss: 1.3159 | Val Seg Loss: 0.2245 | Val Cls Loss: 1.2879
# Validation Classification Metrics -> Accuracy: 0.4103, F1: 0.4045, Sensitivity: 0.4103
# Epoch 11/20 | Train Seg Loss: 0.2293 | Train Cls Loss: 1.2826 | Val Seg Loss: 0.2372 | Val Cls Loss: 1.3066
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4608, Sensitivity: 0.4744
# Epoch 12/20 | Train Seg Loss: 0.2355 | Train Cls Loss: 1.3023 | Val Seg Loss: 0.2072 | Val Cls Loss: 1.2947
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3739, Sensitivity: 0.3974
# Epoch 13/20 | Train Seg Loss: 0.2210 | Train Cls Loss: 1.2752 | Val Seg Loss: 0.2110 | Val Cls Loss: 1.2324
# Validation Classification Metrics -> Accuracy: 0.5256, F1: 0.5014, Sensitivity: 0.5256
# Epoch 14/20 | Train Seg Loss: 0.2049 | Train Cls Loss: 1.2879 | Val Seg Loss: 0.1990 | Val Cls Loss: 1.2713
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4489, Sensitivity: 0.4744
# Epoch 15/20 | Train Seg Loss: 0.1942 | Train Cls Loss: 1.2752 | Val Seg Loss: 0.1878 | Val Cls Loss: 1.2440
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.5063, Sensitivity: 0.5128
# Epoch 16/20 | Train Seg Loss: 0.1878 | Train Cls Loss: 1.2694 | Val Seg Loss: 0.1833 | Val Cls Loss: 1.2483
# Validation Classification Metrics -> Accuracy: 0.4359, F1: 0.3946, Sensitivity: 0.4359
# Epoch 17/20 | Train Seg Loss: 0.1857 | Train Cls Loss: 1.2689 | Val Seg Loss: 0.1778 | Val Cls Loss: 1.2177
# Validation Classification Metrics -> Accuracy: 0.5256, F1: 0.5076, Sensitivity: 0.5256
# Epoch 18/20 | Train Seg Loss: 0.1845 | Train Cls Loss: 1.2309 | Val Seg Loss: 0.1726 | Val Cls Loss: 1.2657
# Validation Classification Metrics -> Accuracy: 0.4487, F1: 0.4396, Sensitivity: 0.4487
# Epoch 19/20 | Train Seg Loss: 0.1714 | Train Cls Loss: 1.2605 | Val Seg Loss: 0.1576 | Val Cls Loss: 1.2358
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.4189, Sensitivity: 0.4231
# Epoch 20/20 | Train Seg Loss: 0.1640 | Train Cls Loss: 1.2058 | Val Seg Loss: 0.1505 | Val Cls Loss: 1.2110
# Validation Classification Metrics -> Accuracy: 0.4359, F1: 0.4296, Sensitivity: 0.4359

# %%
import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

unet = AttentionUNet(in_channels=3, out_channels=1).to(device)
classifier = ClassifierCNNMLP(in_channels=64, num_classes=5).to(device)

criterion_seg = nn.BCEWithLogitsLoss()
criterion_cls = nn.CrossEntropyLoss()

optimizer_unet = optim.Adam(unet.parameters(), lr=1e-4)
optimizer_classifier = optim.Adam(classifier.parameters(), lr=1e-4)

num_epochs = 40  

train_loop(unet, classifier, device, train_loader, val_loader, 
           optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls, num_epochs)
# Out:
# Epoch 1/40 | Train Seg Loss: 0.3727 | Train Cls Loss: 1.5382 | Val Seg Loss: 0.3104 | Val Cls Loss: 1.4974
# Validation Classification Metrics -> Accuracy: 0.3333, F1: 0.2725, Sensitivity: 0.3333
# Epoch 2/40 | Train Seg Loss: 0.2776 | Train Cls Loss: 1.4811 | Val Seg Loss: 0.2522 | Val Cls Loss: 1.4209
# Validation Classification Metrics -> Accuracy: 0.3462, F1: 0.3180, Sensitivity: 0.3462
# Epoch 3/40 | Train Seg Loss: 0.2510 | Train Cls Loss: 1.4481 | Val Seg Loss: 0.2487 | Val Cls Loss: 1.6954
# Validation Classification Metrics -> Accuracy: 0.3333, F1: 0.2473, Sensitivity: 0.3333
# Epoch 4/40 | Train Seg Loss: 0.2296 | Train Cls Loss: 1.4239 | Val Seg Loss: 0.2093 | Val Cls Loss: 1.3751
# Validation Classification Metrics -> Accuracy: 0.3462, F1: 0.3171, Sensitivity: 0.3462
# Epoch 5/40 | Train Seg Loss: 0.2186 | Train Cls Loss: 1.3887 | Val Seg Loss: 0.1975 | Val Cls Loss: 1.3888
# Validation Classification Metrics -> Accuracy: 0.3846, F1: 0.3405, Sensitivity: 0.3846
# Epoch 6/40 | Train Seg Loss: 0.2039 | Train Cls Loss: 1.3906 | Val Seg Loss: 0.1923 | Val Cls Loss: 1.3634
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3545, Sensitivity: 0.3974
# Epoch 7/40 | Train Seg Loss: 0.1908 | Train Cls Loss: 1.3594 | Val Seg Loss: 0.1764 | Val Cls Loss: 1.3307
# Validation Classification Metrics -> Accuracy: 0.4103, F1: 0.3748, Sensitivity: 0.4103
# Epoch 8/40 | Train Seg Loss: 0.1838 | Train Cls Loss: 1.3324 | Val Seg Loss: 0.1744 | Val Cls Loss: 1.3058
# Validation Classification Metrics -> Accuracy: 0.4359, F1: 0.4135, Sensitivity: 0.4359
# Epoch 9/40 | Train Seg Loss: 0.1741 | Train Cls Loss: 1.3477 | Val Seg Loss: 0.1670 | Val Cls Loss: 1.3556
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.4181, Sensitivity: 0.4231
# Epoch 10/40 | Train Seg Loss: 0.1670 | Train Cls Loss: 1.3613 | Val Seg Loss: 0.1601 | Val Cls Loss: 1.3855
# Validation Classification Metrics -> Accuracy: 0.3205, F1: 0.2967, Sensitivity: 0.3205
# Epoch 11/40 | Train Seg Loss: 0.1581 | Train Cls Loss: 1.3292 | Val Seg Loss: 0.1501 | Val Cls Loss: 1.3187
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3951, Sensitivity: 0.3974
# Epoch 12/40 | Train Seg Loss: 0.1488 | Train Cls Loss: 1.3217 | Val Seg Loss: 0.1424 | Val Cls Loss: 1.2862
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4535, Sensitivity: 0.4744
# Epoch 13/40 | Train Seg Loss: 0.1413 | Train Cls Loss: 1.3014 | Val Seg Loss: 0.1341 | Val Cls Loss: 1.3060
# Validation Classification Metrics -> Accuracy: 0.4615, F1: 0.4471, Sensitivity: 0.4615
# Epoch 14/40 | Train Seg Loss: 0.1348 | Train Cls Loss: 1.2791 | Val Seg Loss: 0.1222 | Val Cls Loss: 1.2674
# Validation Classification Metrics -> Accuracy: 0.4359, F1: 0.3905, Sensitivity: 0.4359
# Epoch 15/40 | Train Seg Loss: 0.1295 | Train Cls Loss: 1.2849 | Val Seg Loss: 0.1215 | Val Cls Loss: 1.2719
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4543, Sensitivity: 0.4744
# Epoch 16/40 | Train Seg Loss: 0.1252 | Train Cls Loss: 1.2522 | Val Seg Loss: 0.1166 | Val Cls Loss: 1.2436
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4631, Sensitivity: 0.4744
# Epoch 17/40 | Train Seg Loss: 0.1211 | Train Cls Loss: 1.2654 | Val Seg Loss: 0.1117 | Val Cls Loss: 1.2873
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4356, Sensitivity: 0.4744
# Epoch 18/40 | Train Seg Loss: 0.1164 | Train Cls Loss: 1.2819 | Val Seg Loss: 0.1096 | Val Cls Loss: 1.2462
# Validation Classification Metrics -> Accuracy: 0.4359, F1: 0.4232, Sensitivity: 0.4359
# Epoch 19/40 | Train Seg Loss: 0.1089 | Train Cls Loss: 1.2264 | Val Seg Loss: 0.1070 | Val Cls Loss: 1.2558
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4480, Sensitivity: 0.4744
# Epoch 20/40 | Train Seg Loss: 0.1039 | Train Cls Loss: 1.2487 | Val Seg Loss: 0.0964 | Val Cls Loss: 1.2081
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4555, Sensitivity: 0.4744
# Epoch 21/40 | Train Seg Loss: 0.0983 | Train Cls Loss: 1.2231 | Val Seg Loss: 0.0912 | Val Cls Loss: 1.2744
# Validation Classification Metrics -> Accuracy: 0.4487, F1: 0.4452, Sensitivity: 0.4487
# Epoch 22/40 | Train Seg Loss: 0.0952 | Train Cls Loss: 1.2408 | Val Seg Loss: 0.0926 | Val Cls Loss: 1.1760
# Validation Classification Metrics -> Accuracy: 0.5641, F1: 0.5585, Sensitivity: 0.5641
# Epoch 23/40 | Train Seg Loss: 0.0924 | Train Cls Loss: 1.2217 | Val Seg Loss: 0.0821 | Val Cls Loss: 1.1989
# Validation Classification Metrics -> Accuracy: 0.4615, F1: 0.4498, Sensitivity: 0.4615
# Epoch 24/40 | Train Seg Loss: 0.0882 | Train Cls Loss: 1.2046 | Val Seg Loss: 0.0836 | Val Cls Loss: 1.2168
# Validation Classification Metrics -> Accuracy: 0.4872, F1: 0.4431, Sensitivity: 0.4872
# Epoch 25/40 | Train Seg Loss: 0.0842 | Train Cls Loss: 1.2105 | Val Seg Loss: 0.0786 | Val Cls Loss: 1.1542
# Validation Classification Metrics -> Accuracy: 0.4872, F1: 0.4897, Sensitivity: 0.4872
# Epoch 26/40 | Train Seg Loss: 0.0794 | Train Cls Loss: 1.1881 | Val Seg Loss: 0.0747 | Val Cls Loss: 1.1900
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4649, Sensitivity: 0.4744
# Epoch 27/40 | Train Seg Loss: 0.0766 | Train Cls Loss: 1.2054 | Val Seg Loss: 0.0724 | Val Cls Loss: 1.1700
# Validation Classification Metrics -> Accuracy: 0.5641, F1: 0.5590, Sensitivity: 0.5641
# Epoch 28/40 | Train Seg Loss: 0.0737 | Train Cls Loss: 1.1979 | Val Seg Loss: 0.0701 | Val Cls Loss: 1.1844
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.4806, Sensitivity: 0.5128
# Epoch 29/40 | Train Seg Loss: 0.0728 | Train Cls Loss: 1.1775 | Val Seg Loss: 0.0686 | Val Cls Loss: 1.1728
# Validation Classification Metrics -> Accuracy: 0.4872, F1: 0.4575, Sensitivity: 0.4872
# Epoch 30/40 | Train Seg Loss: 0.0688 | Train Cls Loss: 1.1730 | Val Seg Loss: 0.0636 | Val Cls Loss: 1.1711
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4687, Sensitivity: 0.4744
# Epoch 31/40 | Train Seg Loss: 0.0651 | Train Cls Loss: 1.1599 | Val Seg Loss: 0.0626 | Val Cls Loss: 1.1340
# Validation Classification Metrics -> Accuracy: 0.5385, F1: 0.5207, Sensitivity: 0.5385
# Epoch 32/40 | Train Seg Loss: 0.0629 | Train Cls Loss: 1.1819 | Val Seg Loss: 0.0592 | Val Cls Loss: 1.1471
# Validation Classification Metrics -> Accuracy: 0.5385, F1: 0.5364, Sensitivity: 0.5385
# Epoch 33/40 | Train Seg Loss: 0.0630 | Train Cls Loss: 1.1615 | Val Seg Loss: 0.0575 | Val Cls Loss: 1.1460
# Validation Classification Metrics -> Accuracy: 0.4872, F1: 0.4771, Sensitivity: 0.4872
# Epoch 34/40 | Train Seg Loss: 0.0628 | Train Cls Loss: 1.1697 | Val Seg Loss: 0.0609 | Val Cls Loss: 1.1029
# Validation Classification Metrics -> Accuracy: 0.5513, F1: 0.5429, Sensitivity: 0.5513
# Epoch 35/40 | Train Seg Loss: 0.0600 | Train Cls Loss: 1.1563 | Val Seg Loss: 0.0540 | Val Cls Loss: 1.1286
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.5007, Sensitivity: 0.5128
# Epoch 36/40 | Train Seg Loss: 0.0574 | Train Cls Loss: 1.1411 | Val Seg Loss: 0.0626 | Val Cls Loss: 1.1744
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.4086, Sensitivity: 0.4231
# Epoch 37/40 | Train Seg Loss: 0.0551 | Train Cls Loss: 1.1490 | Val Seg Loss: 0.0511 | Val Cls Loss: 1.1241
# Validation Classification Metrics -> Accuracy: 0.5513, F1: 0.5366, Sensitivity: 0.5513
# Epoch 38/40 | Train Seg Loss: 0.0526 | Train Cls Loss: 1.1552 | Val Seg Loss: 0.0488 | Val Cls Loss: 1.1372
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.4797, Sensitivity: 0.5128
# Epoch 39/40 | Train Seg Loss: 0.0495 | Train Cls Loss: 1.1077 | Val Seg Loss: 0.0481 | Val Cls Loss: 1.0948
# Validation Classification Metrics -> Accuracy: 0.5385, F1: 0.5253, Sensitivity: 0.5385
# Epoch 40/40 | Train Seg Loss: 0.0474 | Train Cls Loss: 1.0868 | Val Seg Loss: 0.0442 | Val Cls Loss: 1.0729
# Validation Classification Metrics -> Accuracy: 0.5513, F1: 0.5290, Sensitivity: 0.5513

# %%
import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

unet = AttentionUNet(in_channels=3, out_channels=1).to(device)
classifier = ClassifierCNNMLP(in_channels=64, num_classes=5).to(device)

criterion_seg = nn.BCEWithLogitsLoss()
criterion_cls = nn.CrossEntropyLoss()

optimizer_unet = optim.Adam(unet.parameters(), lr=1e-4)
optimizer_classifier = optim.Adam(classifier.parameters(), lr=1e-4)

num_epochs = 120  

train_loop(unet, classifier, device, train_loader, val_loader, 
           optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls, num_epochs)
# Out:
# Epoch 1/120 | Train Seg Loss: 0.4292 | Train Cls Loss: 1.5856 | Val Seg Loss: 0.3262 | Val Cls Loss: 1.5248
# Validation Classification Metrics -> Accuracy: 0.2564, F1: 0.1047, Sensitivity: 0.2564
# Epoch 2/120 | Train Seg Loss: 0.3085 | Train Cls Loss: 1.5152 | Val Seg Loss: 0.4434 | Val Cls Loss: 2.4435
# Validation Classification Metrics -> Accuracy: 0.2949, F1: 0.2112, Sensitivity: 0.2949
# Epoch 3/120 | Train Seg Loss: 0.2810 | Train Cls Loss: 1.4729 | Val Seg Loss: 0.2667 | Val Cls Loss: 1.4521
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3498, Sensitivity: 0.3974
# Epoch 4/120 | Train Seg Loss: 0.2583 | Train Cls Loss: 1.4370 | Val Seg Loss: 0.2480 | Val Cls Loss: 1.4104
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.3696, Sensitivity: 0.4231
# Epoch 5/120 | Train Seg Loss: 0.2413 | Train Cls Loss: 1.4410 | Val Seg Loss: 0.2304 | Val Cls Loss: 1.3716
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3253, Sensitivity: 0.3974
# Epoch 6/120 | Train Seg Loss: 0.2363 | Train Cls Loss: 1.4109 | Val Seg Loss: 0.2223 | Val Cls Loss: 1.3840
# Validation Classification Metrics -> Accuracy: 0.3846, F1: 0.3078, Sensitivity: 0.3846
# Epoch 7/120 | Train Seg Loss: 0.2300 | Train Cls Loss: 1.3672 | Val Seg Loss: 0.2177 | Val Cls Loss: 1.3742
# Validation Classification Metrics -> Accuracy: 0.3974, F1: 0.3785, Sensitivity: 0.3974
# Epoch 8/120 | Train Seg Loss: 0.2230 | Train Cls Loss: 1.3587 | Val Seg Loss: 0.2095 | Val Cls Loss: 1.3353
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.4063, Sensitivity: 0.4231
# Epoch 9/120 | Train Seg Loss: 0.2069 | Train Cls Loss: 1.3451 | Val Seg Loss: 0.2010 | Val Cls Loss: 1.2535
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.4231, Sensitivity: 0.4231
# Epoch 10/120 | Train Seg Loss: 0.1962 | Train Cls Loss: 1.3121 | Val Seg Loss: 0.1873 | Val Cls Loss: 1.2432
# Validation Classification Metrics -> Accuracy: 0.5000, F1: 0.4753, Sensitivity: 0.5000
# Epoch 11/120 | Train Seg Loss: 0.1862 | Train Cls Loss: 1.3190 | Val Seg Loss: 0.1762 | Val Cls Loss: 1.2538
# Validation Classification Metrics -> Accuracy: 0.4615, F1: 0.4496, Sensitivity: 0.4615
# Epoch 12/120 | Train Seg Loss: 0.1803 | Train Cls Loss: 1.3196 | Val Seg Loss: 0.1766 | Val Cls Loss: 1.3416
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.3882, Sensitivity: 0.4231
# Epoch 13/120 | Train Seg Loss: 0.1727 | Train Cls Loss: 1.3308 | Val Seg Loss: 0.1685 | Val Cls Loss: 1.2378
# Validation Classification Metrics -> Accuracy: 0.4103, F1: 0.3954, Sensitivity: 0.4103
# Epoch 14/120 | Train Seg Loss: 0.1672 | Train Cls Loss: 1.2959 | Val Seg Loss: 0.1561 | Val Cls Loss: 1.3036
# Validation Classification Metrics -> Accuracy: 0.3718, F1: 0.3499, Sensitivity: 0.3718
# Epoch 15/120 | Train Seg Loss: 0.1583 | Train Cls Loss: 1.2910 | Val Seg Loss: 0.1503 | Val Cls Loss: 1.2576
# Validation Classification Metrics -> Accuracy: 0.4487, F1: 0.4420, Sensitivity: 0.4487
# Epoch 16/120 | Train Seg Loss: 0.1537 | Train Cls Loss: 1.2893 | Val Seg Loss: 0.1451 | Val Cls Loss: 1.1884
# Validation Classification Metrics -> Accuracy: 0.5385, F1: 0.5410, Sensitivity: 0.5385
# Epoch 17/120 | Train Seg Loss: 0.1467 | Train Cls Loss: 1.2609 | Val Seg Loss: 0.1374 | Val Cls Loss: 1.2289
# Validation Classification Metrics -> Accuracy: 0.4231, F1: 0.4012, Sensitivity: 0.4231
# Epoch 18/120 | Train Seg Loss: 0.1397 | Train Cls Loss: 1.2512 | Val Seg Loss: 0.1393 | Val Cls Loss: 1.2929
# Validation Classification Metrics -> Accuracy: 0.4872, F1: 0.4790, Sensitivity: 0.4872
# Epoch 19/120 | Train Seg Loss: 0.1381 | Train Cls Loss: 1.2655 | Val Seg Loss: 0.1232 | Val Cls Loss: 1.2827
# Validation Classification Metrics -> Accuracy: 0.4487, F1: 0.4407, Sensitivity: 0.4487
# Epoch 20/120 | Train Seg Loss: 0.1310 | Train Cls Loss: 1.2463 | Val Seg Loss: 0.1483 | Val Cls Loss: 1.2972
# Validation Classification Metrics -> Accuracy: 0.4359, F1: 0.4084, Sensitivity: 0.4359
# Epoch 21/120 | Train Seg Loss: 0.1278 | Train Cls Loss: 1.2351 | Val Seg Loss: 0.1158 | Val Cls Loss: 1.2300
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4488, Sensitivity: 0.4744
# Epoch 22/120 | Train Seg Loss: 0.1200 | Train Cls Loss: 1.1905 | Val Seg Loss: 0.1150 | Val Cls Loss: 1.1567
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4598, Sensitivity: 0.4744
# Epoch 23/120 | Train Seg Loss: 0.1147 | Train Cls Loss: 1.2383 | Val Seg Loss: 0.1070 | Val Cls Loss: 1.2174
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.4938, Sensitivity: 0.5128
# Epoch 24/120 | Train Seg Loss: 0.1137 | Train Cls Loss: 1.2256 | Val Seg Loss: 0.1047 | Val Cls Loss: 1.1931
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.5028, Sensitivity: 0.5128
# Epoch 25/120 | Train Seg Loss: 0.1070 | Train Cls Loss: 1.1985 | Val Seg Loss: 0.1075 | Val Cls Loss: 1.2286
# Validation Classification Metrics -> Accuracy: 0.4615, F1: 0.4338, Sensitivity: 0.4615
# Epoch 26/120 | Train Seg Loss: 0.1024 | Train Cls Loss: 1.1912 | Val Seg Loss: 0.0957 | Val Cls Loss: 1.2312
# Validation Classification Metrics -> Accuracy: 0.4615, F1: 0.4206, Sensitivity: 0.4615
# Epoch 27/120 | Train Seg Loss: 0.1005 | Train Cls Loss: 1.1843 | Val Seg Loss: 0.0994 | Val Cls Loss: 1.1150
# Validation Classification Metrics -> Accuracy: 0.5385, F1: 0.5311, Sensitivity: 0.5385
# Epoch 28/120 | Train Seg Loss: 0.0974 | Train Cls Loss: 1.2084 | Val Seg Loss: 0.0896 | Val Cls Loss: 1.2173
# Validation Classification Metrics -> Accuracy: 0.5385, F1: 0.5206, Sensitivity: 0.5385
# Epoch 29/120 | Train Seg Loss: 0.0943 | Train Cls Loss: 1.1659 | Val Seg Loss: 0.0935 | Val Cls Loss: 1.1920
# Validation Classification Metrics -> Accuracy: 0.5000, F1: 0.4897, Sensitivity: 0.5000
# Epoch 30/120 | Train Seg Loss: 0.0912 | Train Cls Loss: 1.1877 | Val Seg Loss: 0.0830 | Val Cls Loss: 1.2121
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.5121, Sensitivity: 0.5128
# Epoch 31/120 | Train Seg Loss: 0.0889 | Train Cls Loss: 1.1697 | Val Seg Loss: 0.0793 | Val Cls Loss: 1.1395
# Validation Classification Metrics -> Accuracy: 0.5128, F1: 0.5084, Sensitivity: 0.5128
# Epoch 32/120 | Train Seg Loss: 0.0839 | Train Cls Loss: 1.1743 | Val Seg Loss: 0.0774 | Val Cls Loss: 1.1480
# Validation Classification Metrics -> Accuracy: 0.5385, F1: 0.5224, Sensitivity: 0.5385
# Epoch 33/120 | Train Seg Loss: 0.0812 | Train Cls Loss: 1.1623 | Val Seg Loss: 0.0798 | Val Cls Loss: 1.1516
# Validation Classification Metrics -> Accuracy: 0.4744, F1: 0.4537, Sensitivity: 0.4744
# Epoch 34/120 | Train Seg Loss: 0.0794 | Train Cls Loss: 1.1380 | Val Seg Loss: 0.0723 | Val Cls Loss: 1.1005
# Validation Classification Metrics -> Accuracy: 0.5641, F1: 0.5657, Sensitivity: 0.5641
# Epoch 35/120 | Train Seg Loss: 0.0757 | Train Cls Loss: 1.1194 | Val Seg Loss: 0.0694 | Val Cls Loss: 1.1270
# Validation Classification Metrics -> Accuracy: 0.6154, F1: 0.6127, Sensitivity: 0.6154
# Epoch 36/120 | Train Seg Loss: 0.0733 | Train Cls Loss: 1.1563 | Val Seg Loss: 0.0664 | Val Cls Loss: 1.0794
# Validation Classification Metrics -> Accuracy: 0.6410, F1: 0.6360, Sensitivity: 0.6410
# Epoch 37/120 | Train Seg Loss: 0.0704 | Train Cls Loss: 1.1132 | Val Seg Loss: 0.0655 | Val Cls Loss: 1.0812
# Validation Classification Metrics -> Accuracy: 0.5513, F1: 0.5381, Sensitivity: 0.5513
# Epoch 38/120 | Train Seg Loss: 0.0678 | Train Cls Loss: 1.1037 | Val Seg Loss: 0.0617 | Val Cls Loss: 1.1049
# Validation Classification Metrics -> Accuracy: 0.5641, F1: 0.5529, Sensitivity: 0.5641
# Epoch 39/120 | Train Seg Loss: 0.0675 | Train Cls Loss: 1.1323 | Val Seg Loss: 0.0610 | Val Cls Loss: 1.1063
# Validation Classification Metrics -> Accuracy: 0.5897, F1: 0.5873, Sensitivity: 0.5897
# Epoch 40/120 | Train Seg Loss: 0.0642 | Train Cls Loss: 1.1182 | Val Seg Loss: 0.0579 | Val Cls Loss: 1.1315
# Validation Classification Metrics -> Accuracy: 0.5769, F1: 0.5636, Sensitivity: 0.5769
# Epoch 41/120 | Train Seg Loss: 0.0631 | Train Cls Loss: 1.0859 | Val Seg Loss: 0.0578 | Val Cls Loss: 1.0909
# Validation Classification Metrics -> Accuracy: 0.5769, F1: 0.5790, Sensitivity: 0.5769
# Epoch 42/120 | Train Seg Loss: 0.0602 | Train Cls Loss: 1.1043 | Val Seg Loss: 0.0555 | Val Cls Loss: 1.0377
# Validation Classification Metrics -> Accuracy: 0.5513, F1: 0.5481, Sensitivity: 0.5513
# Epoch 43/120 | Train Seg Loss: 0.0585 | Train Cls Loss: 1.0802 | Val Seg Loss: 0.0535 | Val Cls Loss: 1.0387
# Validation Classification Metrics -> Accuracy: 0.6026, F1: 0.5944, Sensitivity: 0.6026
# Epoch 44/120 | Train Seg Loss: 0.0585 | Train Cls Loss: 1.0746 | Val Seg Loss: 0.0520 | Val Cls Loss: 1.0214
# Validation Classification Metrics -> Accuracy: 0.5513, F1: 0.5470, Sensitivity: 0.5513
# Epoch 45/120 | Train Seg Loss: 0.0561 | Train Cls Loss: 1.0570 | Val Seg Loss: 0.0523 | Val Cls Loss: 1.0607
# Validation Classification Metrics -> Accuracy: 0.5641, F1: 0.5570, Sensitivity: 0.5641
# Epoch 46/120 | Train Seg Loss: 0.0544 | Train Cls Loss: 1.0501 | Val Seg Loss: 0.0492 | Val Cls Loss: 1.0457
# Validation Classification Metrics -> Accuracy: 0.6282, F1: 0.6233, Sensitivity: 0.6282
# Epoch 47/120 | Train Seg Loss: 0.0521 | Train Cls Loss: 1.0471 | Val Seg Loss: 0.0480 | Val Cls Loss: 1.0060
# Validation Classification Metrics -> Accuracy: 0.6410, F1: 0.6395, Sensitivity: 0.6410
# Epoch 48/120 | Train Seg Loss: 0.0510 | Train Cls Loss: 1.0502 | Val Seg Loss: 0.0462 | Val Cls Loss: 1.0468
# Validation Classification Metrics -> Accuracy: 0.6026, F1: 0.5818, Sensitivity: 0.6026
# Epoch 49/120 | Train Seg Loss: 0.0491 | Train Cls Loss: 1.0486 | Val Seg Loss: 0.0461 | Val Cls Loss: 1.0099
# Validation Classification Metrics -> Accuracy: 0.6282, F1: 0.6297, Sensitivity: 0.6282
# Epoch 50/120 | Train Seg Loss: 0.0486 | Train Cls Loss: 1.0446 | Val Seg Loss: 0.0454 | Val Cls Loss: 1.0544
# Validation Classification Metrics -> Accuracy: 0.5256, F1: 0.5107, Sensitivity: 0.5256
# Epoch 51/120 | Train Seg Loss: 0.0474 | Train Cls Loss: 1.0482 | Val Seg Loss: 0.0444 | Val Cls Loss: 1.0462
# Validation Classification Metrics -> Accuracy: 0.6154, F1: 0.6096, Sensitivity: 0.6154
# Epoch 52/120 | Train Seg Loss: 0.0458 | Train Cls Loss: 1.0318 | Val Seg Loss: 0.0418 | Val Cls Loss: 0.9907
# Validation Classification Metrics -> Accuracy: 0.5897, F1: 0.5766, Sensitivity: 0.5897
# Epoch 53/120 | Train Seg Loss: 0.0435 | Train Cls Loss: 1.0122 | Val Seg Loss: 0.0403 | Val Cls Loss: 0.9228
# Validation Classification Metrics -> Accuracy: 0.6667, F1: 0.6703, Sensitivity: 0.6667
# Epoch 54/120 | Train Seg Loss: 0.0416 | Train Cls Loss: 1.0008 | Val Seg Loss: 0.0386 | Val Cls Loss: 0.9143
# Validation Classification Metrics -> Accuracy: 0.6410, F1: 0.6397, Sensitivity: 0.6410
# Epoch 55/120 | Train Seg Loss: 0.0416 | Train Cls Loss: 1.0077 | Val Seg Loss: 0.0385 | Val Cls Loss: 0.9401
# Validation Classification Metrics -> Accuracy: 0.6410, F1: 0.6367, Sensitivity: 0.6410
# Epoch 56/120 | Train Seg Loss: 0.0401 | Train Cls Loss: 0.9774 | Val Seg Loss: 0.0368 | Val Cls Loss: 0.9767
# Validation Classification Metrics -> Accuracy: 0.5769, F1: 0.5724, Sensitivity: 0.5769
# Epoch 57/120 | Train Seg Loss: 0.0398 | Train Cls Loss: 1.0030 | Val Seg Loss: 0.0368 | Val Cls Loss: 0.9766
# Validation Classification Metrics -> Accuracy: 0.5897, F1: 0.5809, Sensitivity: 0.5897
# Epoch 58/120 | Train Seg Loss: 0.0385 | Train Cls Loss: 0.9871 | Val Seg Loss: 0.0347 | Val Cls Loss: 0.9460
# Validation Classification Metrics -> Accuracy: 0.6154, F1: 0.5886, Sensitivity: 0.6154
# Epoch 59/120 | Train Seg Loss: 0.0375 | Train Cls Loss: 0.9552 | Val Seg Loss: 0.0350 | Val Cls Loss: 0.9730
# Validation Classification Metrics -> Accuracy: 0.6538, F1: 0.6511, Sensitivity: 0.6538
# Epoch 60/120 | Train Seg Loss: 0.0371 | Train Cls Loss: 0.9382 | Val Seg Loss: 0.0340 | Val Cls Loss: 0.9825
# Validation Classification Metrics -> Accuracy: 0.6026, F1: 0.5873, Sensitivity: 0.6026
# Epoch 61/120 | Train Seg Loss: 0.0359 | Train Cls Loss: 0.9882 | Val Seg Loss: 0.0321 | Val Cls Loss: 0.9178
# Validation Classification Metrics -> Accuracy: 0.7051, F1: 0.6958, Sensitivity: 0.7051
# Epoch 62/120 | Train Seg Loss: 0.0337 | Train Cls Loss: 0.9269 | Val Seg Loss: 0.0320 | Val Cls Loss: 0.8878
# Validation Classification Metrics -> Accuracy: 0.6538, F1: 0.6500, Sensitivity: 0.6538
# Epoch 63/120 | Train Seg Loss: 0.0331 | Train Cls Loss: 0.9342 | Val Seg Loss: 0.0306 | Val Cls Loss: 0.9555
# Validation Classification Metrics -> Accuracy: 0.6282, F1: 0.6331, Sensitivity: 0.6282
# Epoch 64/120 | Train Seg Loss: 0.0318 | Train Cls Loss: 0.9666 | Val Seg Loss: 0.0299 | Val Cls Loss: 0.8880
# Validation Classification Metrics -> Accuracy: 0.7051, F1: 0.7013, Sensitivity: 0.7051
# Epoch 65/120 | Train Seg Loss: 0.0310 | Train Cls Loss: 0.9148 | Val Seg Loss: 0.0298 | Val Cls Loss: 0.9158
# Validation Classification Metrics -> Accuracy: 0.6026, F1: 0.5962, Sensitivity: 0.6026
# Epoch 66/120 | Train Seg Loss: 0.0307 | Train Cls Loss: 0.9181 | Val Seg Loss: 0.0289 | Val Cls Loss: 0.8751
# Validation Classification Metrics -> Accuracy: 0.7179, F1: 0.7140, Sensitivity: 0.7179
# Epoch 67/120 | Train Seg Loss: 0.0295 | Train Cls Loss: 0.9172 | Val Seg Loss: 0.0275 | Val Cls Loss: 0.8709
# Validation Classification Metrics -> Accuracy: 0.6538, F1: 0.6474, Sensitivity: 0.6538
# Epoch 68/120 | Train Seg Loss: 0.0300 | Train Cls Loss: 0.8740 | Val Seg Loss: 0.0271 | Val Cls Loss: 0.9952
# Validation Classification Metrics -> Accuracy: 0.5897, F1: 0.5805, Sensitivity: 0.5897
# Epoch 69/120 | Train Seg Loss: 0.0296 | Train Cls Loss: 0.9202 | Val Seg Loss: 0.0276 | Val Cls Loss: 0.8815
# Validation Classification Metrics -> Accuracy: 0.6795, F1: 0.6832, Sensitivity: 0.6795
# Epoch 70/120 | Train Seg Loss: 0.0283 | Train Cls Loss: 0.8978 | Val Seg Loss: 0.0264 | Val Cls Loss: 0.8934
# Validation Classification Metrics -> Accuracy: 0.6538, F1: 0.6453, Sensitivity: 0.6538
# Epoch 71/120 | Train Seg Loss: 0.0293 | Train Cls Loss: 0.8974 | Val Seg Loss: 0.0257 | Val Cls Loss: 0.8642
# Validation Classification Metrics -> Accuracy: 0.6923, F1: 0.6832, Sensitivity: 0.6923
# Epoch 72/120 | Train Seg Loss: 0.0315 | Train Cls Loss: 0.8941 | Val Seg Loss: 0.0274 | Val Cls Loss: 0.8409
# Validation Classification Metrics -> Accuracy: 0.6923, F1: 0.6912, Sensitivity: 0.6923
# Epoch 73/120 | Train Seg Loss: 0.0297 | Train Cls Loss: 0.8615 | Val Seg Loss: 0.0262 | Val Cls Loss: 0.8242
# Validation Classification Metrics -> Accuracy: 0.7436, F1: 0.7437, Sensitivity: 0.7436
# Epoch 74/120 | Train Seg Loss: 0.0289 | Train Cls Loss: 0.9228 | Val Seg Loss: 0.0258 | Val Cls Loss: 0.9065
# Validation Classification Metrics -> Accuracy: 0.6410, F1: 0.6378, Sensitivity: 0.6410
# Epoch 75/120 | Train Seg Loss: 0.0273 | Train Cls Loss: 0.8895 | Val Seg Loss: 0.0246 | Val Cls Loss: 0.8170
# Validation Classification Metrics -> Accuracy: 0.7308, F1: 0.7258, Sensitivity: 0.7308
# Epoch 76/120 | Train Seg Loss: 0.0256 | Train Cls Loss: 0.8510 | Val Seg Loss: 0.0236 | Val Cls Loss: 0.8228
# Validation Classification Metrics -> Accuracy: 0.7308, F1: 0.7232, Sensitivity: 0.7308
# Epoch 77/120 | Train Seg Loss: 0.0242 | Train Cls Loss: 0.8450 | Val Seg Loss: 0.0222 | Val Cls Loss: 0.7725
# Validation Classification Metrics -> Accuracy: 0.7436, F1: 0.7348, Sensitivity: 0.7436
# Epoch 78/120 | Train Seg Loss: 0.0232 | Train Cls Loss: 0.8399 | Val Seg Loss: 0.0216 | Val Cls Loss: 0.8623
# Validation Classification Metrics -> Accuracy: 0.6667, F1: 0.6444, Sensitivity: 0.6667
# Epoch 79/120 | Train Seg Loss: 0.0229 | Train Cls Loss: 0.8042 | Val Seg Loss: 0.0214 | Val Cls Loss: 0.7890
# Validation Classification Metrics -> Accuracy: 0.7179, F1: 0.7172, Sensitivity: 0.7179
# Epoch 80/120 | Train Seg Loss: 0.0226 | Train Cls Loss: 0.8087 | Val Seg Loss: 0.0215 | Val Cls Loss: 0.7573
# Validation Classification Metrics -> Accuracy: 0.7051, F1: 0.7031, Sensitivity: 0.7051
# Epoch 81/120 | Train Seg Loss: 0.0225 | Train Cls Loss: 0.8136 | Val Seg Loss: 0.0209 | Val Cls Loss: 0.7871
# Validation Classification Metrics -> Accuracy: 0.7949, F1: 0.7930, Sensitivity: 0.7949
# Epoch 82/120 | Train Seg Loss: 0.0220 | Train Cls Loss: 0.8069 | Val Seg Loss: 0.0201 | Val Cls Loss: 0.7859
# Validation Classification Metrics -> Accuracy: 0.7564, F1: 0.7574, Sensitivity: 0.7564
# Epoch 83/120 | Train Seg Loss: 0.0223 | Train Cls Loss: 0.8184 | Val Seg Loss: 0.0199 | Val Cls Loss: 0.7082
# Validation Classification Metrics -> Accuracy: 0.7821, F1: 0.7818, Sensitivity: 0.7821
# Epoch 84/120 | Train Seg Loss: 0.0228 | Train Cls Loss: 0.7921 | Val Seg Loss: 0.0205 | Val Cls Loss: 0.6839
# Validation Classification Metrics -> Accuracy: 0.7821, F1: 0.7822, Sensitivity: 0.7821
# Epoch 85/120 | Train Seg Loss: 0.0229 | Train Cls Loss: 0.8431 | Val Seg Loss: 0.0213 | Val Cls Loss: 0.8437
# Validation Classification Metrics -> Accuracy: 0.7051, F1: 0.6949, Sensitivity: 0.7051
# Epoch 86/120 | Train Seg Loss: 0.0220 | Train Cls Loss: 0.8626 | Val Seg Loss: 0.0189 | Val Cls Loss: 0.7250
# Validation Classification Metrics -> Accuracy: 0.8077, F1: 0.8041, Sensitivity: 0.8077
# Epoch 87/120 | Train Seg Loss: 0.0203 | Train Cls Loss: 0.7560 | Val Seg Loss: 0.0193 | Val Cls Loss: 0.6956
# Validation Classification Metrics -> Accuracy: 0.7949, F1: 0.7935, Sensitivity: 0.7949
# Epoch 88/120 | Train Seg Loss: 0.0197 | Train Cls Loss: 0.7699 | Val Seg Loss: 0.0184 | Val Cls Loss: 0.8224
# Validation Classification Metrics -> Accuracy: 0.6410, F1: 0.6282, Sensitivity: 0.6410
# Epoch 89/120 | Train Seg Loss: 0.0187 | Train Cls Loss: 0.7794 | Val Seg Loss: 0.0172 | Val Cls Loss: 0.6788
# Validation Classification Metrics -> Accuracy: 0.8077, F1: 0.8077, Sensitivity: 0.8077
# Epoch 90/120 | Train Seg Loss: 0.0186 | Train Cls Loss: 0.7724 | Val Seg Loss: 0.0171 | Val Cls Loss: 0.7379
# Validation Classification Metrics -> Accuracy: 0.7692, F1: 0.7680, Sensitivity: 0.7692
# Epoch 91/120 | Train Seg Loss: 0.0180 | Train Cls Loss: 0.7426 | Val Seg Loss: 0.0169 | Val Cls Loss: 0.6813
# Validation Classification Metrics -> Accuracy: 0.7821, F1: 0.7874, Sensitivity: 0.7821
# Epoch 92/120 | Train Seg Loss: 0.0175 | Train Cls Loss: 0.7472 | Val Seg Loss: 0.0164 | Val Cls Loss: 0.6799
# Validation Classification Metrics -> Accuracy: 0.8077, F1: 0.8050, Sensitivity: 0.8077
# Epoch 93/120 | Train Seg Loss: 0.0176 | Train Cls Loss: 0.7317 | Val Seg Loss: 0.0165 | Val Cls Loss: 0.6548
# Validation Classification Metrics -> Accuracy: 0.7949, F1: 0.7946, Sensitivity: 0.7949
# Epoch 94/120 | Train Seg Loss: 0.0168 | Train Cls Loss: 0.7176 | Val Seg Loss: 0.0161 | Val Cls Loss: 0.6391
# Validation Classification Metrics -> Accuracy: 0.7821, F1: 0.7823, Sensitivity: 0.7821
# Epoch 95/120 | Train Seg Loss: 0.0164 | Train Cls Loss: 0.7342 | Val Seg Loss: 0.0149 | Val Cls Loss: 0.6604
# Validation Classification Metrics -> Accuracy: 0.7949, F1: 0.7964, Sensitivity: 0.7949
# Epoch 96/120 | Train Seg Loss: 0.0165 | Train Cls Loss: 0.7268 | Val Seg Loss: 0.0153 | Val Cls Loss: 0.6686
# Validation Classification Metrics -> Accuracy: 0.7949, F1: 0.7959, Sensitivity: 0.7949
# Epoch 97/120 | Train Seg Loss: 0.0158 | Train Cls Loss: 0.6949 | Val Seg Loss: 0.0150 | Val Cls Loss: 0.6449
# Validation Classification Metrics -> Accuracy: 0.8333, F1: 0.8357, Sensitivity: 0.8333
# Epoch 98/120 | Train Seg Loss: 0.0153 | Train Cls Loss: 0.6973 | Val Seg Loss: 0.0145 | Val Cls Loss: 0.6319
# Validation Classification Metrics -> Accuracy: 0.8205, F1: 0.8215, Sensitivity: 0.8205
# Epoch 99/120 | Train Seg Loss: 0.0156 | Train Cls Loss: 0.7048 | Val Seg Loss: 0.0148 | Val Cls Loss: 0.6359
# Validation Classification Metrics -> Accuracy: 0.8333, F1: 0.8319, Sensitivity: 0.8333
# Epoch 100/120 | Train Seg Loss: 0.0156 | Train Cls Loss: 0.6985 | Val Seg Loss: 0.0145 | Val Cls Loss: 0.6062
# Validation Classification Metrics -> Accuracy: 0.8590, F1: 0.8586, Sensitivity: 0.8590
# Epoch 101/120 | Train Seg Loss: 0.0150 | Train Cls Loss: 0.6740 | Val Seg Loss: 0.0140 | Val Cls Loss: 0.6301
# Validation Classification Metrics -> Accuracy: 0.8462, F1: 0.8452, Sensitivity: 0.8462
# Epoch 102/120 | Train Seg Loss: 0.0153 | Train Cls Loss: 0.6909 | Val Seg Loss: 0.0138 | Val Cls Loss: 0.6857
# Validation Classification Metrics -> Accuracy: 0.7821, F1: 0.7830, Sensitivity: 0.7821
# Epoch 103/120 | Train Seg Loss: 0.0147 | Train Cls Loss: 0.6493 | Val Seg Loss: 0.0139 | Val Cls Loss: 0.6350
# Validation Classification Metrics -> Accuracy: 0.8462, F1: 0.8466, Sensitivity: 0.8462
# Epoch 104/120 | Train Seg Loss: 0.0143 | Train Cls Loss: 0.6581 | Val Seg Loss: 0.0134 | Val Cls Loss: 0.5656
# Validation Classification Metrics -> Accuracy: 0.8718, F1: 0.8686, Sensitivity: 0.8718
# Epoch 105/120 | Train Seg Loss: 0.0137 | Train Cls Loss: 0.6586 | Val Seg Loss: 0.0129 | Val Cls Loss: 0.5797
# Validation Classification Metrics -> Accuracy: 0.8590, F1: 0.8601, Sensitivity: 0.8590
# Epoch 106/120 | Train Seg Loss: 0.0137 | Train Cls Loss: 0.6891 | Val Seg Loss: 0.0127 | Val Cls Loss: 0.5785
# Validation Classification Metrics -> Accuracy: 0.8590, F1: 0.8610, Sensitivity: 0.8590
# Epoch 107/120 | Train Seg Loss: 0.0144 | Train Cls Loss: 0.7043 | Val Seg Loss: 0.0133 | Val Cls Loss: 0.6582
# Validation Classification Metrics -> Accuracy: 0.8333, F1: 0.8389, Sensitivity: 0.8333
# Epoch 108/120 | Train Seg Loss: 0.0139 | Train Cls Loss: 0.6692 | Val Seg Loss: 0.0135 | Val Cls Loss: 0.5209
# Validation Classification Metrics -> Accuracy: 0.9231, F1: 0.9221, Sensitivity: 0.9231
# Epoch 109/120 | Train Seg Loss: 0.0248 | Train Cls Loss: 0.8099 | Val Seg Loss: 0.0268 | Val Cls Loss: 1.1312
# Validation Classification Metrics -> Accuracy: 0.5769, F1: 0.5729, Sensitivity: 0.5769
# Epoch 110/120 | Train Seg Loss: 0.0286 | Train Cls Loss: 0.8313 | Val Seg Loss: 0.0206 | Val Cls Loss: 0.6764
# Validation Classification Metrics -> Accuracy: 0.8718, F1: 0.8676, Sensitivity: 0.8718
# Epoch 111/120 | Train Seg Loss: 0.0207 | Train Cls Loss: 0.7278 | Val Seg Loss: 0.0179 | Val Cls Loss: 0.6578
# Validation Classification Metrics -> Accuracy: 0.8462, F1: 0.8457, Sensitivity: 0.8462
# Epoch 112/120 | Train Seg Loss: 0.0193 | Train Cls Loss: 0.6896 | Val Seg Loss: 0.0157 | Val Cls Loss: 0.5560
# Validation Classification Metrics -> Accuracy: 0.8718, F1: 0.8688, Sensitivity: 0.8718
# Epoch 113/120 | Train Seg Loss: 0.0165 | Train Cls Loss: 0.7010 | Val Seg Loss: 0.0139 | Val Cls Loss: 0.5466
# Validation Classification Metrics -> Accuracy: 0.8590, F1: 0.8574, Sensitivity: 0.8590
# Epoch 114/120 | Train Seg Loss: 0.0151 | Train Cls Loss: 0.6486 | Val Seg Loss: 0.0133 | Val Cls Loss: 0.5347
# Validation Classification Metrics -> Accuracy: 0.8846, F1: 0.8831, Sensitivity: 0.8846
# Epoch 115/120 | Train Seg Loss: 0.0137 | Train Cls Loss: 0.6346 | Val Seg Loss: 0.0124 | Val Cls Loss: 0.5280
# Validation Classification Metrics -> Accuracy: 0.8974, F1: 0.8983, Sensitivity: 0.8974
# Epoch 116/120 | Train Seg Loss: 0.0139 | Train Cls Loss: 0.6077 | Val Seg Loss: 0.0122 | Val Cls Loss: 0.5377
# Validation Classification Metrics -> Accuracy: 0.8718, F1: 0.8719, Sensitivity: 0.8718
# Epoch 117/120 | Train Seg Loss: 0.0134 | Train Cls Loss: 0.6121 | Val Seg Loss: 0.0116 | Val Cls Loss: 0.4841
# Validation Classification Metrics -> Accuracy: 0.8974, F1: 0.8987, Sensitivity: 0.8974
# Epoch 118/120 | Train Seg Loss: 0.0131 | Train Cls Loss: 0.5909 | Val Seg Loss: 0.0118 | Val Cls Loss: 0.5313
# Validation Classification Metrics -> Accuracy: 0.8718, F1: 0.8713, Sensitivity: 0.8718
# Epoch 119/120 | Train Seg Loss: 0.0124 | Train Cls Loss: 0.5698 | Val Seg Loss: 0.0113 | Val Cls Loss: 0.5493
# Validation Classification Metrics -> Accuracy: 0.8590, F1: 0.8598, Sensitivity: 0.8590
# Epoch 120/120 | Train Seg Loss: 0.0119 | Train Cls Loss: 0.6040 | Val Seg Loss: 0.0107 | Val Cls Loss: 0.4671
# Validation Classification Metrics -> Accuracy: 0.9103, F1: 0.9087, Sensitivity: 0.9103

# %%
torch.save(unet.state_dict(), "unet_model.pth")
torch.save(classifier.state_dict(), "classifier_model.pth")

# %%
import torch

# ذخیره دو مدل + optimizer + epoch
torch.save({
    'unet_state_dict': unet.state_dict(),
    'classifier_state_dict': classifier.state_dict(),
    'optimizer_unet_state_dict': optimizer_unet.state_dict(),
    'optimizer_classifier_state_dict': optimizer_classifier.state_dict(),
    'epoch': 120
}, "joint_models_checkpoint.pth")

# %%
import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

unet = AttentionUNet(in_channels=3, out_channels=1).to(device)
classifier = ClassifierCNNMLP(in_channels=64, num_classes=5).to(device)

criterion_seg = nn.BCEWithLogitsLoss()
criterion_cls = nn.CrossEntropyLoss()

optimizer_unet = optim.Adam(unet.parameters(), lr=1e-4)
optimizer_classifier = optim.Adam(classifier.parameters(), lr=1e-4)

num_epochs = 1

# کال کردن train_loop و ذخیره خروجی‌ها
train_losses_seg, val_losses_seg, train_losses_cls, val_losses_cls, val_preds_cls, val_labels_cls, train_preds_cls, train_labels_cls, val_preds_seg, val_labels_seg = train_loop(
    unet, classifier, device, train_loader, val_loader, 
    optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls, num_epochs
)


class_names = ["Class 0", "Class 1", "Class 2", "Class 3", "Class 4"]  # اسم کلاس‌ها رو متناسب با پروژه خودت اصلاح کن
plot_confusion_matrix(val_preds_cls, val_labels_cls, class_names=class_names, dataset_type="Validation")

plot_confusion_matrix(train_preds_cls, train_labels_cls, class_names=class_names, dataset_type="Train")

plot_losses(train_losses_seg, val_losses_seg, train_losses_cls, val_losses_cls)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 19
#      16 num_epochs = 1
#      18 # کال کردن train_loop و ذخیره خروجی‌ها
# ---> 19 train_losses_seg, val_losses_seg, train_losses_cls, val_losses_cls, val_preds_cls, val_labels_cls, train_preds_cls, train_labels_cls, val_preds_seg, val_labels_seg = train_loop(
#      20     unet, classifier, device, train_loader, val_loader,
#      21     optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls, num_epochs
#      22 )
#      25 class_names = ["Class 0", "Class 1", "Class 2", "Class 3", "Class 4"]  # اسم کلاس‌ها رو متناسب با پروژه خودت اصلاح کن
#      26 plot_confusion_matrix(val_preds_cls, val_labels_cls, class_names=class_names, dataset_type="Validation")
#
# Cell In[21], line 219, in train_loop(unet, classifier, device, train_loader, val_loader, optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls, epochs, patience)
#     216 patience_counter = 0
#     218 for epoch in range(1, epochs+1):
# --> 219     train_loss_seg, train_loss_cls, train_preds_seg, train_labels_seg, train_preds_cls, train_labels_cls = train_one_epoch(
#     220         unet, classifier, device, train_loader,
#     221         optimizer_unet, optimizer_classifier,
#     222         criterion_seg, criterion_cls)
#     224     val_loss_seg, val_loss_cls, val_preds_seg, val_labels_seg, val_preds_cls, val_labels_cls = validate_one_epoch(
#     225         unet, classifier, device, val_loader, criterion_seg, criterion_cls)
#     227     # --- محاسبه متریک‌ها ---
#
# Cell In[21], line 62, in train_one_epoch(unet, classifier, device, train_loader, optimizer_unet, optimizer_classifier, criterion_seg, criterion_cls)
#      59 loss_seg.backward()
#      60 optimizer_unet.step()
# ---> 62 total_loss_seg += loss_seg.item()
#      64 # ذخیره نتایج segmentation (قبل از تابع فعالسازی)
#      65 all_preds_seg.append(torch.sigmoid(preds_seg).detach().cpu())  # تبدیل logits به احتمالات
#
# KeyboardInterrupt:

# %%
# تست یک نمونه از Dataset
sample_idx = 0
image, label, mask = full_dataset[sample_idx]

print("🔍 بررسی خروجی Dataset:")
print(f"Image shape: {image.shape}")  # باید (3, 256, 256) باشد
print(f"Label: {label}")  # باید یک عدد صحیح باشد
print(f"Mask shape: {mask.shape}")  # باید (1, 256, 256) باشد
print(f"Mask values range: [{mask.min():.3f}, {mask.max():.3f}]")  # باید بین 0 و 1 باشد

# نمایش تصویر و ماسک
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(image.permute(1, 2, 0))  # تبدیل به (H, W, C)
plt.title(f"Image - Label: {label}")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(mask.squeeze(), cmap='gray')  # حذف بعد کانال
plt.title("Mask")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(image.permute(1, 2, 0))
plt.imshow(mask.squeeze(), cmap='jet', alpha=0.5)  # overlay ماسک
plt.title("Overlay")
plt.axis('off')

plt.show()

# تست DataLoader
print("\n🔍 بررسی DataLoader:")
for batch_idx, (images, labels, masks) in enumerate(train_loader):
    print(f"Batch {batch_idx}:")
    print(f"  Images shape: {images.shape}")  # باید (16, 3, 256, 256) باشد
    print(f"  Labels shape: {labels.shape}")  # باید (16,) باشد
    print(f"  Masks shape: {masks.shape}")   # باید (16, 1, 256, 256) باشد
    if batch_idx == 1:  # فقط دو batch اول را نشان بده
        break
# Out:
# 🔍 بررسی خروجی Dataset:
# Image shape: torch.Size([3, 256, 256])
# Label: 0
# Mask shape: torch.Size([1, 256, 256])
# Mask values range: [1.000, 1.000]
# 🔍 بررسی DataLoader:
# Batch 0:
#   Images shape: torch.Size([16, 3, 256, 256])
#   Labels shape: torch.Size([16])
#   Masks shape: torch.Size([16, 1, 256, 256])
# Batch 1:
#   Images shape: torch.Size([16, 3, 256, 256])
#   Labels shape: torch.Size([16])
#   Masks shape: torch.Size([16, 1, 256, 256])
