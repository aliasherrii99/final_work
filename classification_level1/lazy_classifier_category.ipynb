# %% [markdown]
# category

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


feat_path   = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_Resnet50.xlsx"
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

feat_df = pd.read_excel(feat_path, header=None)
feat_df.rename(columns={feat_df.columns[0]: "name"}, inplace=True)
feat_df["name"] = feat_df["name"].astype(str).str.replace(".png", "", regex=False)


feat_png = feat_df["name"].astype(str) + ".jpg"

label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label_df = label_df[label_df["name"].isin(feat_png)]
feat_df['name'] = feat_df['name'] + '.jpg'
data = feat_df.merge(label_df, on="name", how="inner")

X = data.drop(columns=["name", "category", 'type', 'grade'])
y = data["category"]

le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Accuracy", ascending=False)
print(results.head(10)) 
best_model_name = results.index[0]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


feat_path   = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_Resnet18.xlsx"
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

feat_df = pd.read_excel(feat_path, header=None)
feat_df.rename(columns={feat_df.columns[0]: "name"}, inplace=True)
feat_df["name"] = feat_df["name"].astype(str).str.replace(".png", "", regex=False)


feat_png = feat_df["name"].astype(str) + ".jpg"

label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label_df = label_df[label_df["name"].isin(feat_png)]
feat_df['name'] = feat_df['name'] + '.jpg'
data = feat_df.merge(label_df, on="name", how="inner")

X = data.drop(columns=["name", "category", 'type', 'grade'])
y = data["category"]

le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Balanced Accuracy", ascending=False)
print(results.head(10))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


feat_path   = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_VGG16.xlsx"
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

feat_df = pd.read_excel(feat_path, header=None)
feat_df.rename(columns={feat_df.columns[0]: "name"}, inplace=True)
feat_df["name"] = feat_df["name"].astype(str).str.replace(".png", "", regex=False)


feat_png = feat_df["name"].astype(str) + ".jpg"

label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label_df = label_df[label_df["name"].isin(feat_png)]
feat_df['name'] = feat_df['name'] + '.jpg'
data = feat_df.merge(label_df, on="name", how="inner")

X = data.drop(columns=["name", "category", 'type', 'grade'])
y = data["category"]

le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Balanced Accuracy", ascending=False)
print(results.head(10))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


feat_path   = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_ViTTiny.xlsx"
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

feat_df = pd.read_excel(feat_path, header=None)
feat_df.rename(columns={feat_df.columns[0]: "name"}, inplace=True)
feat_df["name"] = feat_df["name"].astype(str).str.replace(".png", "", regex=False)


feat_png = feat_df["name"].astype(str) + ".jpg"

label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label_df = label_df[label_df["name"].isin(feat_png)]
feat_df['name'] = feat_df['name'] + '.jpg'
data = feat_df.merge(label_df, on="name", how="inner")

X = data.drop(columns=["name", "category", 'type', 'grade'])
y = data["category"]

le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Balanced Accuracy", ascending=False)
print(results.head(10))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


feat_path   = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_DenseNet121.xlsx"
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

feat_df = pd.read_excel(feat_path, header=None)
feat_df.rename(columns={feat_df.columns[0]: "name"}, inplace=True)
feat_df["name"] = feat_df["name"].astype(str).str.replace(".png", "", regex=False)


feat_png = feat_df["name"].astype(str) + ".jpg"

label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label_df = label_df[label_df["name"].isin(feat_png)]
feat_df['name'] = feat_df['name'] + '.jpg'
data = feat_df.merge(label_df, on="name", how="inner")

X = data.drop(columns=["name", "category", 'type', 'grade'])
y = data["category"]

le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Balanced Accuracy", ascending=False)
print(results.head(10))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


feat_path   = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_EfficientNetB0.xlsx"
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

feat_df = pd.read_excel(feat_path, header=None)
feat_df.rename(columns={feat_df.columns[0]: "name"}, inplace=True)
feat_df["name"] = feat_df["name"].astype(str).str.replace(".png", "", regex=False)


feat_png = feat_df["name"].astype(str) + ".jpg"

label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label_df = label_df[label_df["name"].isin(feat_png)]
feat_df['name'] = feat_df['name'] + '.jpg'
data = feat_df.merge(label_df, on="name", how="inner")

X = data.drop(columns=["name", "category", 'type', 'grade'])
y = data["category"]

le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Balanced Accuracy", ascending=False)
print(results.head(10))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


feat_path   = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_MobileNetV3Small.xlsx"
label_path  = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

feat_df = pd.read_excel(feat_path, header=None)
feat_df.rename(columns={feat_df.columns[0]: "name"}, inplace=True)
feat_df["name"] = feat_df["name"].astype(str).str.replace(".png", "", regex=False)


feat_png = feat_df["name"].astype(str) + ".jpg"

label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
label_df = label_df[label_df["name"].isin(feat_png)]
feat_df['name'] = feat_df['name'] + '.jpg'
data = feat_df.merge(label_df, on="name", how="inner")

X = data.drop(columns=["name", "category", 'type', 'grade'])
y = data["category"]

le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Balanced Accuracy", ascending=False)
print(results.head(10))

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from lazypredict.Supervised import LazyClassifier

# مسیرهای جدید برای داده‌های تست پردازش‌شده
test_feat_path = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_Resnet50_TEST.xlsx"  # تغییر داده شد!
label_path = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\scientificProject\data\labels.csv"

# --- بخش داده‌های تست ---
# بارگذاری ویژگی‌های تست (پردازش‌شده با مدل Segmentation)
test_feat_df = pd.read_excel(test_feat_path, header=None)
test_feat_df.rename(columns={test_feat_df.columns[0]: "name"}, inplace=True)
test_feat_df["name"] = test_feat_df["name"].astype(str).str.replace(".png", "", regex=False) + ".jpg"

# بارگذاری لیبل‌ها و تطابق با داده‌های تست
label_df = pd.read_csv(label_path)
label_df["name"] = label_df["name"].astype(str)
test_data = test_feat_df.merge(label_df, on="name", how="inner")

# جدا کردن ویژگی‌ها و لیبل‌های تست
X_test = test_data.drop(columns=["name", "category", 'type', 'grade'])
y_test = LabelEncoder().fit_transform(test_data["category"])

train_feat_path = r"C:\Users\Meta Pc\PycharmProjects\pythonProject\myproject\payanName\my_work\classification_level1\Extracted_features\features_Resnet50.xlsx"
train_feat_df = pd.read_excel(train_feat_path, header=None)
train_feat_df.rename(columns={train_feat_df.columns[0]: "name"}, inplace=True)
train_feat_df["name"] = train_feat_df["name"].astype(str).str.replace(".png", "", regex=False) + ".jpg"
train_data = train_feat_df.merge(label_df, on="name", how="inner")
X_train = train_data.drop(columns=["name", "category", 'type', 'grade'])
y_train = LabelEncoder().fit_transform(train_data["category"])

clf = LazyClassifier(verbose=1, ignore_warnings=True, random_state=42)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

results = predictions.sort_values("Balanced Accuracy", ascending=False)
print(results.head(10))
